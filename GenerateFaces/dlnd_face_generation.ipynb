# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# Archive:  processed_celeba_small.zip
# replace processed_celeba_small/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    # define transformation, resize to 128x128, create tensor
    transform = transforms.Compose([transforms.Resize(image_size), transforms.ToTensor()])
    data = datasets.ImageFolder(data_dir, transform = transform) # define datasets

    # create and return DataLoaders
    dataloader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    X_min, X_max = feature_range
    x = x*(X_max - X_min) + X_min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.7882)
# Max:  tensor(0.8824)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
# helper conv function
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    # Creates a convolutional layer, with optional batch normalization.
    
    layers = []
    
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer) # append conv layer

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels)) # append batchnorm layer
     
    return nn.Sequential(*layers) # Sequential container

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim       
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # first layer, no batch_norm
        self.conv2 = conv(conv_dim, conv_dim*2, 4)
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4)

        self.fc = nn.Linear(4*4*conv_dim*4, 1)     # final, fully-connected layer

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward network, all hidden layers + leaky relu activation
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        
        x = x.view(-1, 4*4*self.conv_dim*4) # flatten the image
        
        x = self.fc(x) # fully-connected layer
        
        return x
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    ## TODO: Complete this function
    ## create a sequence of transpose + optional batch norm layers
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)

    layers.append(deconv_layer) # append conv layer

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels)) # append batchnorm layer


    return nn.Sequential(*layers)  # using Sequential container

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        self.conv_dim = conv_dim
        
        # define first fully-connected layer
        self.fc = nn.Linear(z_size, 4*4*conv_dim*4)
        
        # define transpose conv layers
        self.tran_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.tran_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.tran_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        
        # define a tanh layer for the last layer
        self.tanh = nn.Tanh()
    
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4)  # (batch_size, depth, 4, 4)
        
        # upsampling
        x = F.relu(self.tran_conv1(x)) # hidden transpose conv layers + relu
        x = F.relu(self.tran_conv2(x)) # hidden transpose conv layers + relu
        x = self.tanh(self.tran_conv3(x)) # last layer + tanh activation
        
        return x    
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    # Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        m.weight.data.normal_(0., 0.02)
        # for bias
        if hasattr(m, 'bias') and m.bias is not None:
            m.bias.data.fill_(0.)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (tran_conv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tran_conv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tran_conv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (tanh): Tanh()
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size) #real labels = 1
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()  # binary cross entropy with logits loss
    loss = criterion(D_out.squeeze(), labels) # calculate loss
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) #fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            # compute discriminator loss on real images
            if train_on_gpu:
                real_images = real_images.cuda()
                
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # generate fake images
            # generate fake image
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            # use gpu
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # compute discriminator loss on fake images
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            # compute total loss at Discriminator and perform backward + opti
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # compute discriminator loss on fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            
            # Add up loss and perform backprop
            g_loss = real_loss(D_fake)
            
            # perform backprop and opti
            g_loss.backward()
            g_optimizer.step()
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
from workspace_utils import active_session

with active_session():
    losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/  100] | d_loss: 0.3586 | g_loss: 4.0973
# Epoch [    1/  100] | d_loss: 0.4058 | g_loss: 3.0205
# Epoch [    1/  100] | d_loss: 0.6060 | g_loss: 3.6642
# Epoch [    1/  100] | d_loss: 0.9803 | g_loss: 1.3909
# Epoch [    1/  100] | d_loss: 0.6706 | g_loss: 1.4349
# Epoch [    1/  100] | d_loss: 0.7475 | g_loss: 1.2908
# Epoch [    1/  100] | d_loss: 0.7973 | g_loss: 2.1671
# Epoch [    1/  100] | d_loss: 1.2214 | g_loss: 1.1434
# Epoch [    1/  100] | d_loss: 0.9291 | g_loss: 1.8797
# Epoch [    1/  100] | d_loss: 1.0448 | g_loss: 0.6242
# Epoch [    1/  100] | d_loss: 0.9610 | g_loss: 1.5435
# Epoch [    1/  100] | d_loss: 1.0068 | g_loss: 1.6425
# Epoch [    1/  100] | d_loss: 1.0912 | g_loss: 1.0268
# Epoch [    1/  100] | d_loss: 1.1484 | g_loss: 0.8062
# Epoch [    1/  100] | d_loss: 0.9352 | g_loss: 1.1178
# Epoch [    2/  100] | d_loss: 1.0127 | g_loss: 1.6184
# Epoch [    2/  100] | d_loss: 1.1000 | g_loss: 1.2912
# Epoch [    2/  100] | d_loss: 1.0694 | g_loss: 0.9278
# Epoch [    2/  100] | d_loss: 1.0528 | g_loss: 1.2141
# Epoch [    2/  100] | d_loss: 1.0509 | g_loss: 1.4888
# Epoch [    2/  100] | d_loss: 1.2324 | g_loss: 1.0481
# Epoch [    2/  100] | d_loss: 0.9610 | g_loss: 1.5547
# Epoch [    2/  100] | d_loss: 1.0105 | g_loss: 1.6314
# Epoch [    2/  100] | d_loss: 0.9315 | g_loss: 0.8951
# Epoch [    2/  100] | d_loss: 1.1592 | g_loss: 1.4479
# Epoch [    2/  100] | d_loss: 1.0664 | g_loss: 0.6134
# Epoch [    2/  100] | d_loss: 1.0721 | g_loss: 1.3588
# Epoch [    2/  100] | d_loss: 1.1652 | g_loss: 2.1393
# Epoch [    2/  100] | d_loss: 0.9900 | g_loss: 0.9349
# Epoch [    2/  100] | d_loss: 1.0042 | g_loss: 1.4819
# Epoch [    3/  100] | d_loss: 1.3673 | g_loss: 1.2218
# Epoch [    3/  100] | d_loss: 0.9503 | g_loss: 1.1027
# Epoch [    3/  100] | d_loss: 1.1960 | g_loss: 0.6453
# Epoch [    3/  100] | d_loss: 1.1343 | g_loss: 1.1003
# Epoch [    3/  100] | d_loss: 1.1080 | g_loss: 1.5881
# Epoch [    3/  100] | d_loss: 1.0632 | g_loss: 1.2035
# Epoch [    3/  100] | d_loss: 1.0265 | g_loss: 1.0519
# Epoch [    3/  100] | d_loss: 1.2651 | g_loss: 0.6240
# Epoch [    3/  100] | d_loss: 1.0640 | g_loss: 1.1885
# Epoch [    3/  100] | d_loss: 1.1321 | g_loss: 1.5114
# Epoch [    3/  100] | d_loss: 1.0857 | g_loss: 1.8796
# Epoch [    3/  100] | d_loss: 1.0564 | g_loss: 1.3930
# Epoch [    3/  100] | d_loss: 1.1470 | g_loss: 1.0611
# Epoch [    3/  100] | d_loss: 1.0735 | g_loss: 1.1397
# Epoch [    3/  100] | d_loss: 1.1078 | g_loss: 1.4559
# Epoch [    4/  100] | d_loss: 0.9144 | g_loss: 1.3557
# Epoch [    4/  100] | d_loss: 1.2018 | g_loss: 1.7297
# Epoch [    4/  100] | d_loss: 0.9977 | g_loss: 1.1522
# Epoch [    4/  100] | d_loss: 0.9824 | g_loss: 1.0300
# Epoch [    4/  100] | d_loss: 0.8100 | g_loss: 1.9690
# Epoch [    4/  100] | d_loss: 0.9406 | g_loss: 1.0142
# Epoch [    4/  100] | d_loss: 0.9793 | g_loss: 1.5707
# Epoch [    4/  100] | d_loss: 1.3741 | g_loss: 2.4517
# Epoch [    4/  100] | d_loss: 0.9643 | g_loss: 1.4747
# Epoch [    4/  100] | d_loss: 1.3576 | g_loss: 1.9204
# Epoch [    4/  100] | d_loss: 1.1322 | g_loss: 0.8802
# Epoch [    4/  100] | d_loss: 0.9934 | g_loss: 1.1623
# Epoch [    4/  100] | d_loss: 0.9119 | g_loss: 1.1939
# Epoch [    4/  100] | d_loss: 0.8926 | g_loss: 1.3091
# Epoch [    4/  100] | d_loss: 1.3937 | g_loss: 0.6810
# Epoch [    5/  100] | d_loss: 1.0494 | g_loss: 1.0807
# Epoch [    5/  100] | d_loss: 0.8456 | g_loss: 1.0229
# Epoch [    5/  100] | d_loss: 0.8717 | g_loss: 1.9649
# Epoch [    5/  100] | d_loss: 0.8426 | g_loss: 1.2725
# Epoch [    5/  100] | d_loss: 0.9608 | g_loss: 0.8584
# Epoch [    5/  100] | d_loss: 0.7106 | g_loss: 1.5315
# Epoch [    5/  100] | d_loss: 1.0188 | g_loss: 1.7406
# Epoch [    5/  100] | d_loss: 0.9848 | g_loss: 1.6702
# Epoch [    5/  100] | d_loss: 0.9004 | g_loss: 1.5483
# Epoch [    5/  100] | d_loss: 1.0709 | g_loss: 1.5389
# Epoch [    5/  100] | d_loss: 1.0124 | g_loss: 1.4234
# Epoch [    5/  100] | d_loss: 1.1052 | g_loss: 2.0702
# Epoch [    5/  100] | d_loss: 1.1533 | g_loss: 1.2931
# Epoch [    5/  100] | d_loss: 0.8113 | g_loss: 1.2920
# Epoch [    5/  100] | d_loss: 0.8636 | g_loss: 1.0951
# Epoch [    6/  100] | d_loss: 1.0261 | g_loss: 0.8217
# Epoch [    6/  100] | d_loss: 0.8489 | g_loss: 1.5727
# Epoch [    6/  100] | d_loss: 1.0795 | g_loss: 1.0666
# Epoch [    6/  100] | d_loss: 0.9389 | g_loss: 1.8650
# Epoch [    6/  100] | d_loss: 1.1478 | g_loss: 1.4004
# Epoch [    6/  100] | d_loss: 1.6552 | g_loss: 3.1752
# Epoch [    6/  100] | d_loss: 1.0122 | g_loss: 0.9368
# Epoch [    6/  100] | d_loss: 1.0523 | g_loss: 0.9370
# Epoch [    6/  100] | d_loss: 1.0093 | g_loss: 1.5446
# Epoch [    6/  100] | d_loss: 0.7176 | g_loss: 1.4608
# Epoch [    6/  100] | d_loss: 0.9045 | g_loss: 1.3668
# Epoch [    6/  100] | d_loss: 0.8643 | g_loss: 1.6700
# Epoch [    6/  100] | d_loss: 0.9112 | g_loss: 1.1705
# Epoch [    6/  100] | d_loss: 0.8823 | g_loss: 1.3018
# Epoch [    6/  100] | d_loss: 0.6321 | g_loss: 1.7971
# Epoch [    7/  100] | d_loss: 0.7844 | g_loss: 1.2162
# Epoch [    7/  100] | d_loss: 0.8302 | g_loss: 1.1471
# Epoch [    7/  100] | d_loss: 1.6862 | g_loss: 0.3244
# Epoch [    7/  100] | d_loss: 1.0792 | g_loss: 1.8561
# Epoch [    7/  100] | d_loss: 0.7884 | g_loss: 2.1636
# Epoch [    7/  100] | d_loss: 0.9669 | g_loss: 0.5562
# Epoch [    7/  100] | d_loss: 1.3155 | g_loss: 2.2403
# Epoch [    7/  100] | d_loss: 1.2626 | g_loss: 1.5459
# Epoch [    7/  100] | d_loss: 0.8571 | g_loss: 1.5461
# Epoch [    7/  100] | d_loss: 0.9216 | g_loss: 1.4038
# Epoch [    7/  100] | d_loss: 0.9184 | g_loss: 1.6495
# Epoch [    7/  100] | d_loss: 1.2102 | g_loss: 0.9764
# Epoch [    7/  100] | d_loss: 0.8550 | g_loss: 1.4808
# Epoch [    7/  100] | d_loss: 0.8900 | g_loss: 1.3946
# Epoch [    7/  100] | d_loss: 1.2997 | g_loss: 3.2966
# Epoch [    8/  100] | d_loss: 0.8090 | g_loss: 1.6782
# Epoch [    8/  100] | d_loss: 1.0601 | g_loss: 0.7433
# Epoch [    8/  100] | d_loss: 1.2146 | g_loss: 0.5624
# Epoch [    8/  100] | d_loss: 1.0486 | g_loss: 1.3008
# Epoch [    8/  100] | d_loss: 0.8832 | g_loss: 1.8202
# Epoch [    8/  100] | d_loss: 0.9185 | g_loss: 1.2486
# Epoch [    8/  100] | d_loss: 0.8894 | g_loss: 0.9707
# Epoch [    8/  100] | d_loss: 0.6920 | g_loss: 2.4856
# Epoch [    8/  100] | d_loss: 0.8309 | g_loss: 1.4068
# Epoch [    8/  100] | d_loss: 0.9871 | g_loss: 1.3209
# Epoch [    8/  100] | d_loss: 0.8156 | g_loss: 1.1833
# Epoch [    8/  100] | d_loss: 0.9138 | g_loss: 1.5126
# Epoch [    8/  100] | d_loss: 0.8766 | g_loss: 1.2389
# Epoch [    8/  100] | d_loss: 0.7554 | g_loss: 1.5194
# Epoch [    8/  100] | d_loss: 0.9018 | g_loss: 2.1233
# Epoch [    9/  100] | d_loss: 0.8011 | g_loss: 1.6677
# Epoch [    9/  100] | d_loss: 0.9852 | g_loss: 1.3565
# Epoch [    9/  100] | d_loss: 0.8878 | g_loss: 1.1404
# Epoch [    9/  100] | d_loss: 0.8777 | g_loss: 2.0887
# Epoch [    9/  100] | d_loss: 0.8933 | g_loss: 1.8166
# Epoch [    9/  100] | d_loss: 0.8011 | g_loss: 1.3245
# Epoch [    9/  100] | d_loss: 1.1504 | g_loss: 1.2390
# Epoch [    9/  100] | d_loss: 0.7645 | g_loss: 1.3178
# Epoch [    9/  100] | d_loss: 0.8406 | g_loss: 1.2379
# Epoch [    9/  100] | d_loss: 1.2614 | g_loss: 2.3236
# Epoch [    9/  100] | d_loss: 0.8903 | g_loss: 1.4433
# Epoch [    9/  100] | d_loss: 1.0189 | g_loss: 2.0303
# Epoch [    9/  100] | d_loss: 0.9126 | g_loss: 0.9496
# Epoch [    9/  100] | d_loss: 0.9970 | g_loss: 1.8487
# Epoch [    9/  100] | d_loss: 1.0808 | g_loss: 1.0674
# Epoch [   10/  100] | d_loss: 0.7794 | g_loss: 1.3360
# Epoch [   10/  100] | d_loss: 0.9783 | g_loss: 1.7278
# Epoch [   10/  100] | d_loss: 0.7354 | g_loss: 1.2317
# Epoch [   10/  100] | d_loss: 0.8327 | g_loss: 0.9151
# Epoch [   10/  100] | d_loss: 0.8604 | g_loss: 1.3236
# Epoch [   10/  100] | d_loss: 1.2159 | g_loss: 1.1205
# Epoch [   10/  100] | d_loss: 0.8282 | g_loss: 1.2498
# Epoch [   10/  100] | d_loss: 0.8337 | g_loss: 1.3205
# Epoch [   10/  100] | d_loss: 0.9487 | g_loss: 1.3359
# Epoch [   10/  100] | d_loss: 0.8945 | g_loss: 1.2896
# Epoch [   10/  100] | d_loss: 0.9979 | g_loss: 0.9561
# Epoch [   10/  100] | d_loss: 0.8803 | g_loss: 1.2770
# Epoch [   10/  100] | d_loss: 0.8872 | g_loss: 1.5901
# Epoch [   10/  100] | d_loss: 1.1296 | g_loss: 1.7088
# Epoch [   10/  100] | d_loss: 1.3882 | g_loss: 0.6872
# Epoch [   11/  100] | d_loss: 0.8779 | g_loss: 1.2446
# Epoch [   11/  100] | d_loss: 0.8461 | g_loss: 1.5480
# Epoch [   11/  100] | d_loss: 0.8287 | g_loss: 0.9317
# Epoch [   11/  100] | d_loss: 1.2026 | g_loss: 0.4579
# Epoch [   11/  100] | d_loss: 0.9407 | g_loss: 0.9109
# Epoch [   11/  100] | d_loss: 1.1164 | g_loss: 0.8361
# Epoch [   11/  100] | d_loss: 1.0452 | g_loss: 2.3678
# Epoch [   11/  100] | d_loss: 0.9362 | g_loss: 1.6107
# Epoch [   11/  100] | d_loss: 0.9293 | g_loss: 0.9976
# Epoch [   11/  100] | d_loss: 0.7365 | g_loss: 1.8281
# Epoch [   11/  100] | d_loss: 0.9938 | g_loss: 0.8558
# Epoch [   11/  100] | d_loss: 0.7291 | g_loss: 1.7782
# Epoch [   11/  100] | d_loss: 0.9428 | g_loss: 1.2543
# Epoch [   11/  100] | d_loss: 0.8396 | g_loss: 1.5750
# Epoch [   11/  100] | d_loss: 1.4235 | g_loss: 2.4822
# Epoch [   12/  100] | d_loss: 1.1229 | g_loss: 1.7469
# Epoch [   12/  100] | d_loss: 0.8243 | g_loss: 1.2613
# Epoch [   12/  100] | d_loss: 1.3555 | g_loss: 3.0949
# Epoch [   12/  100] | d_loss: 0.7343 | g_loss: 1.9332
# Epoch [   12/  100] | d_loss: 0.9345 | g_loss: 1.2360
# Epoch [   12/  100] | d_loss: 1.0808 | g_loss: 0.8832
# Epoch [   12/  100] | d_loss: 0.9108 | g_loss: 1.2058
# Epoch [   12/  100] | d_loss: 0.6714 | g_loss: 1.4091
# Epoch [   12/  100] | d_loss: 0.8902 | g_loss: 1.4566
# Epoch [   12/  100] | d_loss: 0.7929 | g_loss: 1.0429
# Epoch [   12/  100] | d_loss: 0.8700 | g_loss: 0.7730
# Epoch [   12/  100] | d_loss: 0.8017 | g_loss: 1.5627
# Epoch [   12/  100] | d_loss: 0.9586 | g_loss: 1.0600
# Epoch [   12/  100] | d_loss: 1.0257 | g_loss: 2.0328
# Epoch [   12/  100] | d_loss: 0.9722 | g_loss: 1.1170
# Epoch [   13/  100] | d_loss: 0.7570 | g_loss: 1.3279
# Epoch [   13/  100] | d_loss: 1.2452 | g_loss: 2.6505
# Epoch [   13/  100] | d_loss: 0.6679 | g_loss: 1.2909
# Epoch [   13/  100] | d_loss: 0.6455 | g_loss: 1.6911
# Epoch [   13/  100] | d_loss: 0.9929 | g_loss: 1.3385
# Epoch [   13/  100] | d_loss: 0.7613 | g_loss: 0.9939
# Epoch [   13/  100] | d_loss: 0.9396 | g_loss: 1.2312
# Epoch [   13/  100] | d_loss: 0.9920 | g_loss: 1.1856
# Epoch [   13/  100] | d_loss: 0.9802 | g_loss: 0.7784
# Epoch [   13/  100] | d_loss: 0.8347 | g_loss: 1.4951
# Epoch [   13/  100] | d_loss: 0.9170 | g_loss: 2.0346
# Epoch [   13/  100] | d_loss: 0.8388 | g_loss: 1.9457
# Epoch [   13/  100] | d_loss: 1.1977 | g_loss: 0.9535
# Epoch [   13/  100] | d_loss: 0.7217 | g_loss: 1.4239
# Epoch [   13/  100] | d_loss: 0.6838 | g_loss: 1.7961
# Epoch [   14/  100] | d_loss: 0.7260 | g_loss: 1.5201
# Epoch [   14/  100] | d_loss: 0.8168 | g_loss: 0.9639
# Epoch [   14/  100] | d_loss: 0.8402 | g_loss: 2.2260
# Epoch [   14/  100] | d_loss: 0.9644 | g_loss: 2.6422
# Epoch [   14/  100] | d_loss: 0.7246 | g_loss: 1.4988
# Epoch [   14/  100] | d_loss: 0.8102 | g_loss: 1.3317
# Epoch [   14/  100] | d_loss: 0.7386 | g_loss: 2.0178
# Epoch [   14/  100] | d_loss: 0.8513 | g_loss: 1.8225
# Epoch [   14/  100] | d_loss: 0.9375 | g_loss: 1.3896
# Epoch [   14/  100] | d_loss: 0.7082 | g_loss: 1.3987
# Epoch [   14/  100] | d_loss: 0.7979 | g_loss: 2.0589
# Epoch [   14/  100] | d_loss: 0.7985 | g_loss: 1.5928
# Epoch [   14/  100] | d_loss: 0.8495 | g_loss: 1.1173
# Epoch [   14/  100] | d_loss: 0.6063 | g_loss: 1.6353
# Epoch [   14/  100] | d_loss: 0.9085 | g_loss: 0.6469
# Epoch [   15/  100] | d_loss: 1.4648 | g_loss: 3.0960
# Epoch [   15/  100] | d_loss: 0.8291 | g_loss: 1.4625
# Epoch [   15/  100] | d_loss: 0.7410 | g_loss: 1.6247
# Epoch [   15/  100] | d_loss: 0.8050 | g_loss: 1.1093
# Epoch [   15/  100] | d_loss: 1.1862 | g_loss: 0.9897
# Epoch [   15/  100] | d_loss: 0.7947 | g_loss: 1.2656
# Epoch [   15/  100] | d_loss: 0.9385 | g_loss: 1.7625
# Epoch [   15/  100] | d_loss: 0.6038 | g_loss: 2.0395
# Epoch [   15/  100] | d_loss: 1.0879 | g_loss: 2.7211
# Epoch [   15/  100] | d_loss: 0.7798 | g_loss: 2.1840
# Epoch [   15/  100] | d_loss: 0.7164 | g_loss: 1.5135
# Epoch [   15/  100] | d_loss: 0.7439 | g_loss: 1.5825
# Epoch [   15/  100] | d_loss: 0.7199 | g_loss: 1.5141
# Epoch [   15/  100] | d_loss: 0.8194 | g_loss: 2.1078
# Epoch [   15/  100] | d_loss: 0.7377 | g_loss: 1.2585
# Epoch [   16/  100] | d_loss: 0.5810 | g_loss: 1.6422
# Epoch [   16/  100] | d_loss: 0.7345 | g_loss: 1.4353
# Epoch [   16/  100] | d_loss: 1.1642 | g_loss: 0.9485
# Epoch [   16/  100] | d_loss: 0.6022 | g_loss: 1.7685
# Epoch [   16/  100] | d_loss: 0.7575 | g_loss: 1.2632
# Epoch [   16/  100] | d_loss: 0.6347 | g_loss: 1.1825
# Epoch [   16/  100] | d_loss: 0.6863 | g_loss: 1.2104
# Epoch [   16/  100] | d_loss: 2.1390 | g_loss: 4.6602
# Epoch [   16/  100] | d_loss: 0.6436 | g_loss: 2.1956
# Epoch [   16/  100] | d_loss: 1.0266 | g_loss: 2.4808
# Epoch [   16/  100] | d_loss: 0.5877 | g_loss: 1.9913
# Epoch [   16/  100] | d_loss: 0.7289 | g_loss: 1.1675
# Epoch [   16/  100] | d_loss: 0.6886 | g_loss: 1.6621
# Epoch [   16/  100] | d_loss: 0.7165 | g_loss: 2.1308
# Epoch [   16/  100] | d_loss: 0.5240 | g_loss: 1.7722
# Epoch [   17/  100] | d_loss: 0.5823 | g_loss: 1.9838
# Epoch [   17/  100] | d_loss: 0.8004 | g_loss: 0.8474
# Epoch [   17/  100] | d_loss: 0.6094 | g_loss: 1.6815
# Epoch [   17/  100] | d_loss: 0.6167 | g_loss: 1.9811
# Epoch [   17/  100] | d_loss: 0.6437 | g_loss: 1.9387
# Epoch [   17/  100] | d_loss: 0.6969 | g_loss: 2.0780
# Epoch [   17/  100] | d_loss: 0.6536 | g_loss: 1.7987
# Epoch [   17/  100] | d_loss: 0.7660 | g_loss: 2.6699
# Epoch [   17/  100] | d_loss: 0.6009 | g_loss: 1.3281
# Epoch [   17/  100] | d_loss: 0.6992 | g_loss: 1.8885
# Epoch [   17/  100] | d_loss: 0.5772 | g_loss: 1.8121
# Epoch [   17/  100] | d_loss: 0.6320 | g_loss: 2.3481
# Epoch [   17/  100] | d_loss: 0.8767 | g_loss: 1.0317
# Epoch [   17/  100] | d_loss: 0.5537 | g_loss: 1.8497
# Epoch [   17/  100] | d_loss: 0.4049 | g_loss: 2.7138
# Epoch [   18/  100] | d_loss: 0.5415 | g_loss: 2.2429
# Epoch [   18/  100] | d_loss: 0.5314 | g_loss: 1.6477
# Epoch [   18/  100] | d_loss: 0.6307 | g_loss: 2.1871
# Epoch [   18/  100] | d_loss: 0.8427 | g_loss: 1.5606
# Epoch [   18/  100] | d_loss: 0.6720 | g_loss: 2.2066
# Epoch [   18/  100] | d_loss: 0.4836 | g_loss: 1.8694
# Epoch [   18/  100] | d_loss: 0.6732 | g_loss: 1.9721
# Epoch [   18/  100] | d_loss: 0.9071 | g_loss: 0.6156
# Epoch [   18/  100] | d_loss: 0.5776 | g_loss: 2.0211
# Epoch [   18/  100] | d_loss: 0.5187 | g_loss: 1.8524
# Epoch [   18/  100] | d_loss: 0.6451 | g_loss: 2.0189
# Epoch [   18/  100] | d_loss: 0.8268 | g_loss: 1.2598
# Epoch [   18/  100] | d_loss: 0.8685 | g_loss: 1.5675
# Epoch [   18/  100] | d_loss: 0.5532 | g_loss: 2.2524
# Epoch [   18/  100] | d_loss: 0.6124 | g_loss: 2.3216
# Epoch [   19/  100] | d_loss: 1.3482 | g_loss: 2.9772
# Epoch [   19/  100] | d_loss: 0.4942 | g_loss: 1.4547
# Epoch [   19/  100] | d_loss: 0.4708 | g_loss: 1.5972
# Epoch [   19/  100] | d_loss: 0.7199 | g_loss: 2.3671
# Epoch [   19/  100] | d_loss: 0.5517 | g_loss: 1.5143
# Epoch [   19/  100] | d_loss: 0.4326 | g_loss: 2.1853
# Epoch [   19/  100] | d_loss: 1.7418 | g_loss: 0.1216
# Epoch [   19/  100] | d_loss: 0.7949 | g_loss: 0.9404
# Epoch [   19/  100] | d_loss: 0.5692 | g_loss: 2.2657
# Epoch [   19/  100] | d_loss: 0.7656 | g_loss: 1.0502
# Epoch [   19/  100] | d_loss: 0.4863 | g_loss: 1.6027
# Epoch [   19/  100] | d_loss: 0.7590 | g_loss: 2.8922
# Epoch [   19/  100] | d_loss: 0.8191 | g_loss: 3.7007
# Epoch [   19/  100] | d_loss: 0.6821 | g_loss: 2.5046
# Epoch [   19/  100] | d_loss: 0.7433 | g_loss: 3.1286
# Epoch [   20/  100] | d_loss: 0.5696 | g_loss: 2.7293
# Epoch [   20/  100] | d_loss: 0.5480 | g_loss: 1.3727
# Epoch [   20/  100] | d_loss: 0.5606 | g_loss: 1.6773
# Epoch [   20/  100] | d_loss: 0.2802 | g_loss: 2.0970
# Epoch [   20/  100] | d_loss: 0.7717 | g_loss: 0.7846
# Epoch [   20/  100] | d_loss: 0.6809 | g_loss: 2.3272
# Epoch [   20/  100] | d_loss: 0.4626 | g_loss: 1.9763
# Epoch [   20/  100] | d_loss: 0.5938 | g_loss: 1.5092
# Epoch [   20/  100] | d_loss: 0.4940 | g_loss: 2.2347
# Epoch [   20/  100] | d_loss: 0.5315 | g_loss: 1.6462
# Epoch [   20/  100] | d_loss: 0.3934 | g_loss: 2.2163
# Epoch [   20/  100] | d_loss: 0.3301 | g_loss: 2.2609
# Epoch [   20/  100] | d_loss: 0.4563 | g_loss: 2.4977
# Epoch [   20/  100] | d_loss: 0.7428 | g_loss: 0.6819
# Epoch [   20/  100] | d_loss: 0.5320 | g_loss: 2.6186
# Epoch [   21/  100] | d_loss: 0.3863 | g_loss: 2.4265
# Epoch [   21/  100] | d_loss: 0.4262 | g_loss: 2.5028
# Epoch [   21/  100] | d_loss: 0.5004 | g_loss: 2.1323
# Epoch [   21/  100] | d_loss: 0.3614 | g_loss: 2.9862
# Epoch [   21/  100] | d_loss: 0.5684 | g_loss: 1.2471
# Epoch [   21/  100] | d_loss: 0.4622 | g_loss: 1.3593
# Epoch [   21/  100] | d_loss: 0.5217 | g_loss: 3.2478
# Epoch [   21/  100] | d_loss: 0.9678 | g_loss: 2.7501
# Epoch [   21/  100] | d_loss: 0.6105 | g_loss: 1.7948
# Epoch [   21/  100] | d_loss: 0.4675 | g_loss: 1.7466
# Epoch [   21/  100] | d_loss: 0.5566 | g_loss: 1.6900
# Epoch [   21/  100] | d_loss: 0.4679 | g_loss: 1.4830
# Epoch [   21/  100] | d_loss: 0.6211 | g_loss: 1.2173
# Epoch [   21/  100] | d_loss: 0.4216 | g_loss: 1.9512
# Epoch [   21/  100] | d_loss: 0.6535 | g_loss: 2.9064
# Epoch [   22/  100] | d_loss: 0.5480 | g_loss: 2.7692
# Epoch [   22/  100] | d_loss: 1.8791 | g_loss: 0.3861
# Epoch [   22/  100] | d_loss: 0.5807 | g_loss: 1.7054
# Epoch [   22/  100] | d_loss: 0.7846 | g_loss: 1.1618
# Epoch [   22/  100] | d_loss: 0.4957 | g_loss: 1.8239
# Epoch [   22/  100] | d_loss: 0.5135 | g_loss: 1.8528
# Epoch [   22/  100] | d_loss: 0.7635 | g_loss: 1.2087
# Epoch [   22/  100] | d_loss: 0.6344 | g_loss: 2.5353
# Epoch [   22/  100] | d_loss: 0.5353 | g_loss: 1.8439
# Epoch [   22/  100] | d_loss: 0.7132 | g_loss: 2.0488
# Epoch [   22/  100] | d_loss: 0.4214 | g_loss: 1.7531
# Epoch [   22/  100] | d_loss: 0.6781 | g_loss: 3.5413
# Epoch [   22/  100] | d_loss: 0.5138 | g_loss: 2.4563
# Epoch [   22/  100] | d_loss: 0.5464 | g_loss: 1.4574
# Epoch [   22/  100] | d_loss: 0.4937 | g_loss: 2.4576
# Epoch [   23/  100] | d_loss: 0.3773 | g_loss: 2.0693
# Epoch [   23/  100] | d_loss: 0.4167 | g_loss: 2.1714
# Epoch [   23/  100] | d_loss: 0.4015 | g_loss: 2.9125
# Epoch [   23/  100] | d_loss: 0.4298 | g_loss: 2.7963
# Epoch [   23/  100] | d_loss: 0.7747 | g_loss: 1.1358
# Epoch [   23/  100] | d_loss: 0.6875 | g_loss: 1.5217
# Epoch [   23/  100] | d_loss: 0.7262 | g_loss: 3.5192
# Epoch [   23/  100] | d_loss: 0.4800 | g_loss: 2.3112
# Epoch [   23/  100] | d_loss: 0.4428 | g_loss: 2.6628
# Epoch [   23/  100] | d_loss: 0.4862 | g_loss: 3.4855
# Epoch [   23/  100] | d_loss: 0.3810 | g_loss: 1.9814
# Epoch [   23/  100] | d_loss: 0.4884 | g_loss: 2.1043
# Epoch [   23/  100] | d_loss: 0.5285 | g_loss: 1.7909
# Epoch [   23/  100] | d_loss: 0.4698 | g_loss: 1.9134
# Epoch [   23/  100] | d_loss: 0.7331 | g_loss: 2.6954
# Epoch [   24/  100] | d_loss: 0.4438 | g_loss: 2.1021
# Epoch [   24/  100] | d_loss: 0.4189 | g_loss: 1.9954
# Epoch [   24/  100] | d_loss: 0.4569 | g_loss: 2.0373
# Epoch [   24/  100] | d_loss: 1.5154 | g_loss: 5.2194
# Epoch [   24/  100] | d_loss: 0.4504 | g_loss: 1.9695
# Epoch [   24/  100] | d_loss: 0.3919 | g_loss: 2.5883
# Epoch [   24/  100] | d_loss: 0.4192 | g_loss: 1.9095
# Epoch [   24/  100] | d_loss: 0.4147 | g_loss: 2.0843
# Epoch [   24/  100] | d_loss: 0.3018 | g_loss: 1.9971
# Epoch [   24/  100] | d_loss: 0.4201 | g_loss: 2.2262
# Epoch [   24/  100] | d_loss: 0.4627 | g_loss: 2.5534
# Epoch [   24/  100] | d_loss: 0.3615 | g_loss: 2.9100
# Epoch [   24/  100] | d_loss: 0.7035 | g_loss: 2.0544
# Epoch [   24/  100] | d_loss: 0.2746 | g_loss: 2.4683
# Epoch [   24/  100] | d_loss: 0.4827 | g_loss: 2.3180
# Epoch [   25/  100] | d_loss: 0.3662 | g_loss: 2.3377
# Epoch [   25/  100] | d_loss: 0.4537 | g_loss: 2.0323
# Epoch [   25/  100] | d_loss: 0.2680 | g_loss: 2.7034
# Epoch [   25/  100] | d_loss: 0.4096 | g_loss: 2.5857
# Epoch [   25/  100] | d_loss: 0.4257 | g_loss: 2.0597
# Epoch [   25/  100] | d_loss: 0.4188 | g_loss: 2.6714
# Epoch [   25/  100] | d_loss: 0.4632 | g_loss: 3.2367
# Epoch [   25/  100] | d_loss: 0.5122 | g_loss: 2.1165
# Epoch [   25/  100] | d_loss: 0.3984 | g_loss: 2.1873
# Epoch [   25/  100] | d_loss: 0.4022 | g_loss: 1.9165
# Epoch [   25/  100] | d_loss: 0.4898 | g_loss: 3.2213
# Epoch [   25/  100] | d_loss: 0.4762 | g_loss: 2.6226
# Epoch [   25/  100] | d_loss: 0.3951 | g_loss: 2.3130
# Epoch [   25/  100] | d_loss: 0.3120 | g_loss: 1.5846
# Epoch [   25/  100] | d_loss: 0.4128 | g_loss: 2.4357
# Epoch [   26/  100] | d_loss: 0.3666 | g_loss: 1.7611
# Epoch [   26/  100] | d_loss: 0.3156 | g_loss: 3.4748
# Epoch [   26/  100] | d_loss: 0.3985 | g_loss: 2.3870
# Epoch [   26/  100] | d_loss: 0.3564 | g_loss: 2.7644
# Epoch [   26/  100] | d_loss: 0.4434 | g_loss: 2.4820
# Epoch [   26/  100] | d_loss: 0.2805 | g_loss: 3.5078
# Epoch [   26/  100] | d_loss: 0.4201 | g_loss: 3.1144
# Epoch [   26/  100] | d_loss: 0.2610 | g_loss: 2.1266
# Epoch [   26/  100] | d_loss: 0.3478 | g_loss: 2.8407
# Epoch [   26/  100] | d_loss: 0.3627 | g_loss: 2.5320
# Epoch [   26/  100] | d_loss: 0.3190 | g_loss: 1.9744
# Epoch [   26/  100] | d_loss: 0.2504 | g_loss: 2.5017
# Epoch [   26/  100] | d_loss: 0.3852 | g_loss: 2.1968
# Epoch [   26/  100] | d_loss: 0.3024 | g_loss: 2.4586
# Epoch [   26/  100] | d_loss: 0.3900 | g_loss: 2.4629
# Epoch [   27/  100] | d_loss: 0.4735 | g_loss: 3.4675
# Epoch [   27/  100] | d_loss: 0.3779 | g_loss: 2.6380
# Epoch [   27/  100] | d_loss: 0.2815 | g_loss: 2.3157
# Epoch [   27/  100] | d_loss: 0.3945 | g_loss: 2.5252
# Epoch [   27/  100] | d_loss: 0.3552 | g_loss: 2.2831
# Epoch [   27/  100] | d_loss: 0.2721 | g_loss: 2.5351
# Epoch [   27/  100] | d_loss: 0.3208 | g_loss: 2.9131
# Epoch [   27/  100] | d_loss: 0.7780 | g_loss: 5.0727
# Epoch [   27/  100] | d_loss: 0.2929 | g_loss: 2.4853
# Epoch [   27/  100] | d_loss: 0.3999 | g_loss: 2.8198
# Epoch [   27/  100] | d_loss: 0.4480 | g_loss: 2.8023
# Epoch [   27/  100] | d_loss: 0.4541 | g_loss: 4.1714
# Epoch [   27/  100] | d_loss: 0.3062 | g_loss: 2.3996
# Epoch [   27/  100] | d_loss: 3.3043 | g_loss: 0.3371
# Epoch [   27/  100] | d_loss: 0.6389 | g_loss: 1.8255
# Epoch [   28/  100] | d_loss: 0.5608 | g_loss: 1.8481
# Epoch [   28/  100] | d_loss: 0.3892 | g_loss: 3.2721
# Epoch [   28/  100] | d_loss: 0.3862 | g_loss: 3.0127
# Epoch [   28/  100] | d_loss: 0.3248 | g_loss: 2.6549
# Epoch [   28/  100] | d_loss: 0.3735 | g_loss: 3.2342
# Epoch [   28/  100] | d_loss: 0.3378 | g_loss: 2.9522
# Epoch [   28/  100] | d_loss: 0.2969 | g_loss: 2.2795
# Epoch [   28/  100] | d_loss: 0.2672 | g_loss: 3.0724
# Epoch [   28/  100] | d_loss: 0.4763 | g_loss: 4.4665
# Epoch [   28/  100] | d_loss: 0.2737 | g_loss: 3.0992
# Epoch [   28/  100] | d_loss: 0.3597 | g_loss: 4.0292
# Epoch [   28/  100] | d_loss: 0.3820 | g_loss: 2.3002
# Epoch [   28/  100] | d_loss: 2.2706 | g_loss: 3.6767
# Epoch [   28/  100] | d_loss: 0.2949 | g_loss: 2.0042
# Epoch [   28/  100] | d_loss: 0.3017 | g_loss: 2.5463
# Epoch [   29/  100] | d_loss: 0.2675 | g_loss: 2.7707
# Epoch [   29/  100] | d_loss: 0.7849 | g_loss: 1.8106
# Epoch [   29/  100] | d_loss: 0.2077 | g_loss: 2.8244
# Epoch [   29/  100] | d_loss: 0.3173 | g_loss: 3.7222
# Epoch [   29/  100] | d_loss: 0.4458 | g_loss: 1.4243
# Epoch [   29/  100] | d_loss: 0.2872 | g_loss: 2.1875
# Epoch [   29/  100] | d_loss: 0.3579 | g_loss: 2.2476
# Epoch [   29/  100] | d_loss: 0.2009 | g_loss: 3.6735
# Epoch [   29/  100] | d_loss: 2.3744 | g_loss: 0.6376
# Epoch [   29/  100] | d_loss: 0.3406 | g_loss: 2.0230
# Epoch [   29/  100] | d_loss: 0.3677 | g_loss: 2.8708
# Epoch [   29/  100] | d_loss: 0.2443 | g_loss: 2.5476
# Epoch [   29/  100] | d_loss: 0.2761 | g_loss: 3.3203
# Epoch [   29/  100] | d_loss: 0.3189 | g_loss: 3.2797
# Epoch [   29/  100] | d_loss: 0.6206 | g_loss: 4.6469
# Epoch [   30/  100] | d_loss: 4.2599 | g_loss: 0.2423
# Epoch [   30/  100] | d_loss: 0.8998 | g_loss: 1.3305
# Epoch [   30/  100] | d_loss: 0.3568 | g_loss: 2.5485
# Epoch [   30/  100] | d_loss: 0.4195 | g_loss: 1.5524
# Epoch [   30/  100] | d_loss: 0.2373 | g_loss: 2.8185
# Epoch [   30/  100] | d_loss: 0.2122 | g_loss: 2.9173
# Epoch [   30/  100] | d_loss: 0.8716 | g_loss: 0.4146
# Epoch [   30/  100] | d_loss: 0.2125 | g_loss: 2.6408
# Epoch [   30/  100] | d_loss: 0.3519 | g_loss: 2.1233
# Epoch [   30/  100] | d_loss: 0.3414 | g_loss: 2.3749
# Epoch [   30/  100] | d_loss: 0.2082 | g_loss: 2.2926
# Epoch [   30/  100] | d_loss: 0.2417 | g_loss: 2.6307
# Epoch [   30/  100] | d_loss: 0.3145 | g_loss: 3.0601
# Epoch [   30/  100] | d_loss: 0.3895 | g_loss: 3.1896
# Epoch [   30/  100] | d_loss: 0.2131 | g_loss: 2.7614
# Epoch [   31/  100] | d_loss: 0.2635 | g_loss: 3.1735
# Epoch [   31/  100] | d_loss: 0.1837 | g_loss: 3.1890
# Epoch [   31/  100] | d_loss: 0.4286 | g_loss: 2.1963
# Epoch [   31/  100] | d_loss: 0.2516 | g_loss: 2.7133
# Epoch [   31/  100] | d_loss: 0.2830 | g_loss: 2.0435
# Epoch [   31/  100] | d_loss: 0.2176 | g_loss: 2.9885
# Epoch [   31/  100] | d_loss: 0.3528 | g_loss: 3.2996
# Epoch [   31/  100] | d_loss: 0.6069 | g_loss: 1.9943
# Epoch [   31/  100] | d_loss: 0.2157 | g_loss: 2.9320
# Epoch [   31/  100] | d_loss: 0.3891 | g_loss: 3.3234
# Epoch [   31/  100] | d_loss: 0.2969 | g_loss: 2.6361
# Epoch [   31/  100] | d_loss: 0.6614 | g_loss: 2.5843
# Epoch [   31/  100] | d_loss: 0.3553 | g_loss: 3.3305
# Epoch [   31/  100] | d_loss: 0.1910 | g_loss: 3.6443
# Epoch [   31/  100] | d_loss: 0.3028 | g_loss: 2.3212
# Epoch [   32/  100] | d_loss: 0.1626 | g_loss: 2.8026
# Epoch [   32/  100] | d_loss: 0.3524 | g_loss: 2.7982
# Epoch [   32/  100] | d_loss: 0.3456 | g_loss: 3.8032
# Epoch [   32/  100] | d_loss: 0.2685 | g_loss: 2.6552
# Epoch [   32/  100] | d_loss: 0.2798 | g_loss: 3.7153
# Epoch [   32/  100] | d_loss: 0.2747 | g_loss: 3.4261
# Epoch [   32/  100] | d_loss: 1.6723 | g_loss: 1.8507
# Epoch [   32/  100] | d_loss: 0.2177 | g_loss: 3.3436
# Epoch [   32/  100] | d_loss: 0.2569 | g_loss: 3.3704
# Epoch [   32/  100] | d_loss: 0.2578 | g_loss: 2.7047
# Epoch [   32/  100] | d_loss: 0.3017 | g_loss: 2.8795
# Epoch [   32/  100] | d_loss: 0.5045 | g_loss: 3.3078
# Epoch [   32/  100] | d_loss: 0.2531 | g_loss: 2.6840
# Epoch [   32/  100] | d_loss: 0.2166 | g_loss: 2.7200
# Epoch [   32/  100] | d_loss: 0.2117 | g_loss: 3.2447
# Epoch [   33/  100] | d_loss: 0.2149 | g_loss: 2.7334
# Epoch [   33/  100] | d_loss: 0.1713 | g_loss: 2.3254
# Epoch [   33/  100] | d_loss: 0.2660 | g_loss: 2.7509
# Epoch [   33/  100] | d_loss: 0.1919 | g_loss: 4.2022
# Epoch [   33/  100] | d_loss: 0.5140 | g_loss: 5.0359
# Epoch [   33/  100] | d_loss: 1.5535 | g_loss: 0.7645
# Epoch [   33/  100] | d_loss: 0.2826 | g_loss: 2.6985
# Epoch [   33/  100] | d_loss: 0.3661 | g_loss: 3.3631
# Epoch [   33/  100] | d_loss: 0.8348 | g_loss: 1.1477
# Epoch [   33/  100] | d_loss: 0.3370 | g_loss: 2.6892
# Epoch [   33/  100] | d_loss: 0.3159 | g_loss: 2.1485
# Epoch [   33/  100] | d_loss: 0.3385 | g_loss: 2.8343
# Epoch [   33/  100] | d_loss: 0.3355 | g_loss: 2.8941
# Epoch [   33/  100] | d_loss: 0.1826 | g_loss: 3.4764
# Epoch [   33/  100] | d_loss: 0.2206 | g_loss: 3.0838
# Epoch [   34/  100] | d_loss: 0.2178 | g_loss: 4.1440
# Epoch [   34/  100] | d_loss: 0.8225 | g_loss: 2.1140
# Epoch [   34/  100] | d_loss: 0.2225 | g_loss: 3.1011
# Epoch [   34/  100] | d_loss: 0.2211 | g_loss: 3.5190
# Epoch [   34/  100] | d_loss: 1.4385 | g_loss: 5.3696
# Epoch [   34/  100] | d_loss: 0.6264 | g_loss: 3.5477
# Epoch [   34/  100] | d_loss: 0.3000 | g_loss: 2.6108
# Epoch [   34/  100] | d_loss: 0.2554 | g_loss: 2.6910
# Epoch [   34/  100] | d_loss: 0.2256 | g_loss: 4.2989
# Epoch [   34/  100] | d_loss: 0.1790 | g_loss: 3.5015
# Epoch [   34/  100] | d_loss: 0.5310 | g_loss: 2.2268
# Epoch [   34/  100] | d_loss: 0.1896 | g_loss: 2.9775
# Epoch [   34/  100] | d_loss: 0.3318 | g_loss: 2.9435
# Epoch [   34/  100] | d_loss: 0.1681 | g_loss: 2.8501
# Epoch [   34/  100] | d_loss: 0.1657 | g_loss: 3.7836
# Epoch [   35/  100] | d_loss: 0.1900 | g_loss: 4.2744
# Epoch [   35/  100] | d_loss: 0.6767 | g_loss: 3.5709
# Epoch [   35/  100] | d_loss: 0.3156 | g_loss: 2.4319
# Epoch [   35/  100] | d_loss: 0.1979 | g_loss: 3.2744
# Epoch [   35/  100] | d_loss: 0.1617 | g_loss: 3.3054
# Epoch [   35/  100] | d_loss: 0.2198 | g_loss: 3.6030
# Epoch [   35/  100] | d_loss: 0.1413 | g_loss: 3.8334
# Epoch [   35/  100] | d_loss: 0.3960 | g_loss: 3.0103
# Epoch [   35/  100] | d_loss: 0.2230 | g_loss: 3.0620
# Epoch [   35/  100] | d_loss: 0.3065 | g_loss: 3.6224
# Epoch [   35/  100] | d_loss: 0.3698 | g_loss: 3.3875
# Epoch [   35/  100] | d_loss: 0.2101 | g_loss: 2.9123
# Epoch [   35/  100] | d_loss: 0.2546 | g_loss: 2.9643
# Epoch [   35/  100] | d_loss: 0.3037 | g_loss: 1.6817
# Epoch [   35/  100] | d_loss: 0.1773 | g_loss: 3.7322
# Epoch [   36/  100] | d_loss: 0.2187 | g_loss: 2.4790
# Epoch [   36/  100] | d_loss: 0.1395 | g_loss: 2.5736
# Epoch [   36/  100] | d_loss: 0.1802 | g_loss: 3.4226
# Epoch [   36/  100] | d_loss: 0.2644 | g_loss: 3.8990
# Epoch [   36/  100] | d_loss: 0.2298 | g_loss: 2.2722
# Epoch [   36/  100] | d_loss: 0.1456 | g_loss: 3.7953
# Epoch [   36/  100] | d_loss: 1.3973 | g_loss: 0.9205
# Epoch [   36/  100] | d_loss: 0.3229 | g_loss: 3.0754
# Epoch [   36/  100] | d_loss: 0.2090 | g_loss: 3.1552
# Epoch [   36/  100] | d_loss: 0.1502 | g_loss: 3.8986
# Epoch [   36/  100] | d_loss: 0.1571 | g_loss: 3.5000
# Epoch [   36/  100] | d_loss: 0.1991 | g_loss: 2.7170
# Epoch [   36/  100] | d_loss: 0.1650 | g_loss: 2.0861
# Epoch [   36/  100] | d_loss: 0.3906 | g_loss: 5.1910
# Epoch [   36/  100] | d_loss: 0.3351 | g_loss: 2.9853
# Epoch [   37/  100] | d_loss: 0.5952 | g_loss: 5.2950
# Epoch [   37/  100] | d_loss: 0.1413 | g_loss: 3.5578
# Epoch [   37/  100] | d_loss: 0.1845 | g_loss: 2.8301
# Epoch [   37/  100] | d_loss: 2.1940 | g_loss: 2.1767
# Epoch [   37/  100] | d_loss: 0.2240 | g_loss: 2.6434
# Epoch [   37/  100] | d_loss: 0.1644 | g_loss: 3.0599
# Epoch [   37/  100] | d_loss: 0.1848 | g_loss: 3.3778
# Epoch [   37/  100] | d_loss: 0.1730 | g_loss: 4.0448
# Epoch [   37/  100] | d_loss: 0.2840 | g_loss: 4.2604
# Epoch [   37/  100] | d_loss: 1.2390 | g_loss: 0.7768
# Epoch [   37/  100] | d_loss: 0.2813 | g_loss: 3.6905
# Epoch [   37/  100] | d_loss: 0.1471 | g_loss: 3.4428
# Epoch [   37/  100] | d_loss: 0.2346 | g_loss: 3.2012
# Epoch [   37/  100] | d_loss: 0.2233 | g_loss: 3.4069
# Epoch [   37/  100] | d_loss: 0.4320 | g_loss: 4.6381
# Epoch [   38/  100] | d_loss: 0.2647 | g_loss: 3.6707
# Epoch [   38/  100] | d_loss: 0.1655 | g_loss: 2.9861
# Epoch [   38/  100] | d_loss: 0.2468 | g_loss: 3.1054
# Epoch [   38/  100] | d_loss: 0.1336 | g_loss: 3.6888
# Epoch [   38/  100] | d_loss: 1.2150 | g_loss: 0.1168
# Epoch [   38/  100] | d_loss: 0.4180 | g_loss: 2.2058
# Epoch [   38/  100] | d_loss: 0.2872 | g_loss: 2.9169
# Epoch [   38/  100] | d_loss: 0.1775 | g_loss: 2.3412
# Epoch [   38/  100] | d_loss: 0.3814 | g_loss: 1.6409
# Epoch [   38/  100] | d_loss: 0.1716 | g_loss: 3.3645
# Epoch [   38/  100] | d_loss: 0.1650 | g_loss: 3.2474
# Epoch [   38/  100] | d_loss: 0.1773 | g_loss: 2.6880
# Epoch [   38/  100] | d_loss: 0.3019 | g_loss: 2.1092
# Epoch [   38/  100] | d_loss: 0.2058 | g_loss: 3.6319
# Epoch [   38/  100] | d_loss: 0.1867 | g_loss: 3.2957
# Epoch [   39/  100] | d_loss: 0.1262 | g_loss: 3.3056
# Epoch [   39/  100] | d_loss: 0.1549 | g_loss: 3.3446
# Epoch [   39/  100] | d_loss: 1.6839 | g_loss: 0.1530
# Epoch [   39/  100] | d_loss: 2.7260 | g_loss: 0.3426
# Epoch [   39/  100] | d_loss: 1.8931 | g_loss: 0.5717
# Epoch [   39/  100] | d_loss: 0.1975 | g_loss: 3.3425
# Epoch [   39/  100] | d_loss: 0.2128 | g_loss: 3.2260
# Epoch [   39/  100] | d_loss: 1.0339 | g_loss: 2.3072
# Epoch [   39/  100] | d_loss: 0.2995 | g_loss: 3.1045
# Epoch [   39/  100] | d_loss: 0.2098 | g_loss: 3.7188
# Epoch [   39/  100] | d_loss: 0.1979 | g_loss: 3.4201
# Epoch [   39/  100] | d_loss: 0.2076 | g_loss: 2.9588
# Epoch [   39/  100] | d_loss: 0.3257 | g_loss: 4.8056
# Epoch [   39/  100] | d_loss: 0.2304 | g_loss: 3.6784
# Epoch [   39/  100] | d_loss: 0.2470 | g_loss: 4.3285
# Epoch [   40/  100] | d_loss: 0.2243 | g_loss: 3.8156
# Epoch [   40/  100] | d_loss: 0.1300 | g_loss: 3.3481
# Epoch [   40/  100] | d_loss: 0.1230 | g_loss: 4.4174
# Epoch [   40/  100] | d_loss: 0.1539 | g_loss: 3.8197
# Epoch [   40/  100] | d_loss: 0.5529 | g_loss: 2.2887
# Epoch [   40/  100] | d_loss: 0.3471 | g_loss: 2.8729
# Epoch [   40/  100] | d_loss: 0.1414 | g_loss: 2.4037
# Epoch [   40/  100] | d_loss: 0.0926 | g_loss: 3.5461
# Epoch [   40/  100] | d_loss: 0.8150 | g_loss: 1.2173
# Epoch [   40/  100] | d_loss: 0.2866 | g_loss: 4.2825
# Epoch [   40/  100] | d_loss: 0.2463 | g_loss: 2.3077
# Epoch [   40/  100] | d_loss: 0.2382 | g_loss: 3.0049
# Epoch [   40/  100] | d_loss: 0.1823 | g_loss: 3.6963
# Epoch [   40/  100] | d_loss: 0.1133 | g_loss: 4.0249
# Epoch [   40/  100] | d_loss: 0.1746 | g_loss: 2.5578
# Epoch [   41/  100] | d_loss: 0.1491 | g_loss: 3.4173
# Epoch [   41/  100] | d_loss: 0.1968 | g_loss: 3.3037
# Epoch [   41/  100] | d_loss: 0.1040 | g_loss: 2.8754
# Epoch [   41/  100] | d_loss: 0.1031 | g_loss: 4.0160
# Epoch [   41/  100] | d_loss: 0.2510 | g_loss: 2.2127
# Epoch [   41/  100] | d_loss: 2.2271 | g_loss: 0.1158
# Epoch [   41/  100] | d_loss: 0.9566 | g_loss: 1.0792
# Epoch [   41/  100] | d_loss: 0.5277 | g_loss: 1.2574
# Epoch [   41/  100] | d_loss: 0.1127 | g_loss: 3.0182
# Epoch [   41/  100] | d_loss: 0.2391 | g_loss: 3.7033
# Epoch [   41/  100] | d_loss: 0.1009 | g_loss: 3.6473
# Epoch [   41/  100] | d_loss: 0.1136 | g_loss: 3.7274
# Epoch [   41/  100] | d_loss: 0.1878 | g_loss: 4.3195
# Epoch [   41/  100] | d_loss: 0.1409 | g_loss: 3.4251
# Epoch [   41/  100] | d_loss: 1.0600 | g_loss: 1.5757
# Epoch [   42/  100] | d_loss: 0.8133 | g_loss: 2.2199
# Epoch [   42/  100] | d_loss: 1.0550 | g_loss: 1.0218
# Epoch [   42/  100] | d_loss: 0.2569 | g_loss: 3.3682
# Epoch [   42/  100] | d_loss: 0.1413 | g_loss: 2.7426
# Epoch [   42/  100] | d_loss: 0.0728 | g_loss: 4.1908
# Epoch [   42/  100] | d_loss: 0.1156 | g_loss: 3.8497
# Epoch [   42/  100] | d_loss: 0.3091 | g_loss: 2.6811
# Epoch [   42/  100] | d_loss: 0.2069 | g_loss: 3.6208
# Epoch [   42/  100] | d_loss: 0.2375 | g_loss: 3.8694
# Epoch [   42/  100] | d_loss: 0.1874 | g_loss: 3.7169
# Epoch [   42/  100] | d_loss: 0.1211 | g_loss: 4.3502
# Epoch [   42/  100] | d_loss: 0.2081 | g_loss: 2.8089
# Epoch [   42/  100] | d_loss: 0.1162 | g_loss: 4.2462
# Epoch [   42/  100] | d_loss: 0.1222 | g_loss: 2.4215
# Epoch [   42/  100] | d_loss: 2.7253 | g_loss: 0.2541
# Epoch [   43/  100] | d_loss: 3.3329 | g_loss: 4.3239
# Epoch [   43/  100] | d_loss: 0.1795 | g_loss: 4.6655
# Epoch [   43/  100] | d_loss: 0.1429 | g_loss: 3.6683
# Epoch [   43/  100] | d_loss: 0.1741 | g_loss: 3.2007
# Epoch [   43/  100] | d_loss: 0.0670 | g_loss: 4.1509
# Epoch [   43/  100] | d_loss: 0.2537 | g_loss: 3.0523
# Epoch [   43/  100] | d_loss: 0.4833 | g_loss: 5.0910
# Epoch [   43/  100] | d_loss: 0.1089 | g_loss: 3.6538
# Epoch [   43/  100] | d_loss: 0.1867 | g_loss: 2.3363
# Epoch [   43/  100] | d_loss: 0.1514 | g_loss: 3.7814
# Epoch [   43/  100] | d_loss: 0.5492 | g_loss: 1.8716
# Epoch [   43/  100] | d_loss: 0.4706 | g_loss: 2.2428
# Epoch [   43/  100] | d_loss: 0.1387 | g_loss: 3.9911
# Epoch [   43/  100] | d_loss: 0.1307 | g_loss: 3.5951
# Epoch [   43/  100] | d_loss: 0.1199 | g_loss: 4.5319
# Epoch [   44/  100] | d_loss: 0.3551 | g_loss: 2.4178
# Epoch [   44/  100] | d_loss: 0.1114 | g_loss: 3.4473
# Epoch [   44/  100] | d_loss: 0.1043 | g_loss: 4.2555
# Epoch [   44/  100] | d_loss: 0.0783 | g_loss: 3.2420
# Epoch [   44/  100] | d_loss: 0.1756 | g_loss: 4.8600
# Epoch [   44/  100] | d_loss: 1.9980 | g_loss: 4.0066
# Epoch [   44/  100] | d_loss: 0.1697 | g_loss: 4.2831
# Epoch [   44/  100] | d_loss: 0.1566 | g_loss: 3.6568
# Epoch [   44/  100] | d_loss: 0.1471 | g_loss: 3.5928
# Epoch [   44/  100] | d_loss: 1.3235 | g_loss: 0.9041
# Epoch [   44/  100] | d_loss: 1.5580 | g_loss: 2.3348
# Epoch [   44/  100] | d_loss: 0.2199 | g_loss: 3.4540
# Epoch [   44/  100] | d_loss: 0.1203 | g_loss: 3.8193
# Epoch [   44/  100] | d_loss: 0.3176 | g_loss: 3.2861
# Epoch [   44/  100] | d_loss: 0.3463 | g_loss: 2.2183
# Epoch [   45/  100] | d_loss: 0.2189 | g_loss: 3.5582
# Epoch [   45/  100] | d_loss: 0.2036 | g_loss: 2.3139
# Epoch [   45/  100] | d_loss: 0.1650 | g_loss: 3.5461
# Epoch [   45/  100] | d_loss: 0.1142 | g_loss: 3.2585
# Epoch [   45/  100] | d_loss: 0.1329 | g_loss: 4.0461
# Epoch [   45/  100] | d_loss: 0.1024 | g_loss: 3.7312
# Epoch [   45/  100] | d_loss: 0.5957 | g_loss: 2.4794
# Epoch [   45/  100] | d_loss: 0.1206 | g_loss: 3.1013
# Epoch [   45/  100] | d_loss: 0.5026 | g_loss: 5.6182
# Epoch [   45/  100] | d_loss: 0.1184 | g_loss: 3.9616
# Epoch [   45/  100] | d_loss: 0.5824 | g_loss: 2.7718
# Epoch [   45/  100] | d_loss: 1.1845 | g_loss: 0.9354
# Epoch [   45/  100] | d_loss: 0.4523 | g_loss: 2.1607
# Epoch [   45/  100] | d_loss: 0.2634 | g_loss: 3.0425
# Epoch [   45/  100] | d_loss: 0.1539 | g_loss: 2.8458
# Epoch [   46/  100] | d_loss: 0.2630 | g_loss: 2.9592
# Epoch [   46/  100] | d_loss: 0.1393 | g_loss: 3.2983
# Epoch [   46/  100] | d_loss: 0.1501 | g_loss: 3.0441
# Epoch [   46/  100] | d_loss: 0.1607 | g_loss: 3.2824
# Epoch [   46/  100] | d_loss: 0.1748 | g_loss: 4.5952
# Epoch [   46/  100] | d_loss: 0.1857 | g_loss: 3.1965
# Epoch [   46/  100] | d_loss: 0.1797 | g_loss: 4.2090
# Epoch [   46/  100] | d_loss: 0.0989 | g_loss: 3.5540
# Epoch [   46/  100] | d_loss: 0.0599 | g_loss: 3.9688
# Epoch [   46/  100] | d_loss: 0.0651 | g_loss: 3.9343
# Epoch [   46/  100] | d_loss: 0.3724 | g_loss: 3.4833
# Epoch [   46/  100] | d_loss: 1.1207 | g_loss: 4.2181
# Epoch [   46/  100] | d_loss: 1.1163 | g_loss: 0.6990
# Epoch [   46/  100] | d_loss: 0.3473 | g_loss: 3.7250
# Epoch [   46/  100] | d_loss: 0.4145 | g_loss: 3.1219
# Epoch [   47/  100] | d_loss: 0.3935 | g_loss: 2.4684
# Epoch [   47/  100] | d_loss: 0.2069 | g_loss: 2.7710
# Epoch [   47/  100] | d_loss: 0.1405 | g_loss: 3.7085
# Epoch [   47/  100] | d_loss: 0.2617 | g_loss: 2.4485
# Epoch [   47/  100] | d_loss: 0.0744 | g_loss: 4.3158
# Epoch [   47/  100] | d_loss: 0.1014 | g_loss: 2.9854
# Epoch [   47/  100] | d_loss: 0.9494 | g_loss: 5.5118
# Epoch [   47/  100] | d_loss: 0.1657 | g_loss: 3.4624
# Epoch [   47/  100] | d_loss: 0.1465 | g_loss: 3.3777
# Epoch [   47/  100] | d_loss: 0.1321 | g_loss: 3.3256
# Epoch [   47/  100] | d_loss: 0.2194 | g_loss: 4.9997
# Epoch [   47/  100] | d_loss: 0.5864 | g_loss: 1.9272
# Epoch [   47/  100] | d_loss: 0.1352 | g_loss: 3.3983
# Epoch [   47/  100] | d_loss: 1.4375 | g_loss: 1.8264
# Epoch [   47/  100] | d_loss: 0.4129 | g_loss: 3.0301
# Epoch [   48/  100] | d_loss: 0.3281 | g_loss: 2.5064
# Epoch [   48/  100] | d_loss: 0.1383 | g_loss: 3.6968
# Epoch [   48/  100] | d_loss: 0.1377 | g_loss: 3.9367
# Epoch [   48/  100] | d_loss: 0.1345 | g_loss: 3.9239
# Epoch [   48/  100] | d_loss: 0.1911 | g_loss: 2.7805
# Epoch [   48/  100] | d_loss: 0.1621 | g_loss: 3.3896
# Epoch [   48/  100] | d_loss: 0.0724 | g_loss: 3.9227
# Epoch [   48/  100] | d_loss: 0.1656 | g_loss: 4.9507
# Epoch [   48/  100] | d_loss: 0.0846 | g_loss: 3.6995
# Epoch [   48/  100] | d_loss: 1.3522 | g_loss: 1.4996
# Epoch [   48/  100] | d_loss: 1.4129 | g_loss: 0.6800
# Epoch [   48/  100] | d_loss: 0.3948 | g_loss: 3.0536
# Epoch [   48/  100] | d_loss: 0.9937 | g_loss: 5.7784
# Epoch [   48/  100] | d_loss: 0.1195 | g_loss: 3.9545
# Epoch [   48/  100] | d_loss: 0.7806 | g_loss: 6.8406
# Epoch [   49/  100] | d_loss: 1.1054 | g_loss: 0.4092
# Epoch [   49/  100] | d_loss: 0.1369 | g_loss: 3.8016
# Epoch [   49/  100] | d_loss: 0.1376 | g_loss: 4.4415
# Epoch [   49/  100] | d_loss: 1.2668 | g_loss: 2.1028
# Epoch [   49/  100] | d_loss: 0.2139 | g_loss: 3.7407
# Epoch [   49/  100] | d_loss: 0.1311 | g_loss: 3.6028
# Epoch [   49/  100] | d_loss: 0.0701 | g_loss: 4.3252
# Epoch [   49/  100] | d_loss: 0.1027 | g_loss: 3.5934
# Epoch [   49/  100] | d_loss: 0.1720 | g_loss: 4.2676
# Epoch [   49/  100] | d_loss: 0.2351 | g_loss: 4.6395
# Epoch [   49/  100] | d_loss: 0.2564 | g_loss: 5.3277
# Epoch [   49/  100] | d_loss: 0.1376 | g_loss: 4.6439
# Epoch [   49/  100] | d_loss: 0.1365 | g_loss: 4.0018
# Epoch [   49/  100] | d_loss: 0.1986 | g_loss: 2.8308
# Epoch [   49/  100] | d_loss: 0.1741 | g_loss: 2.1043
# Epoch [   50/  100] | d_loss: 0.0761 | g_loss: 2.8606
# Epoch [   50/  100] | d_loss: 0.1059 | g_loss: 4.7491
# Epoch [   50/  100] | d_loss: 0.0992 | g_loss: 3.7551
# Epoch [   50/  100] | d_loss: 0.1274 | g_loss: 3.2242
# Epoch [   50/  100] | d_loss: 0.6974 | g_loss: 1.2057
# Epoch [   50/  100] | d_loss: 0.7858 | g_loss: 1.8095
# Epoch [   50/  100] | d_loss: 0.1441 | g_loss: 2.9350
# Epoch [   50/  100] | d_loss: 0.1370 | g_loss: 4.3388
# Epoch [   50/  100] | d_loss: 0.2967 | g_loss: 2.6119
# Epoch [   50/  100] | d_loss: 1.6974 | g_loss: 3.2535
# Epoch [   50/  100] | d_loss: 0.2299 | g_loss: 3.8676
# Epoch [   50/  100] | d_loss: 0.6658 | g_loss: 1.7044
# Epoch [   50/  100] | d_loss: 0.0944 | g_loss: 3.4159
# Epoch [   50/  100] | d_loss: 0.0721 | g_loss: 4.6715
# Epoch [   50/  100] | d_loss: 0.1144 | g_loss: 4.0139
# Epoch [   51/  100] | d_loss: 0.1544 | g_loss: 2.8325
# Epoch [   51/  100] | d_loss: 0.0757 | g_loss: 3.7740
# Epoch [   51/  100] | d_loss: 0.1061 | g_loss: 4.8707
# Epoch [   51/  100] | d_loss: 0.5585 | g_loss: 1.2774
# Epoch [   51/  100] | d_loss: 0.3461 | g_loss: 4.4651
# Epoch [   51/  100] | d_loss: 0.1939 | g_loss: 4.7656
# Epoch [   51/  100] | d_loss: 0.0791 | g_loss: 4.6455
# Epoch [   51/  100] | d_loss: 0.1304 | g_loss: 2.6386
# Epoch [   51/  100] | d_loss: 0.1048 | g_loss: 4.0185
# Epoch [   51/  100] | d_loss: 0.0607 | g_loss: 5.2118
# Epoch [   51/  100] | d_loss: 0.0842 | g_loss: 3.7959
# Epoch [   51/  100] | d_loss: 0.8733 | g_loss: 1.3200
# Epoch [   51/  100] | d_loss: 0.2910 | g_loss: 3.1844
# Epoch [   51/  100] | d_loss: 0.5472 | g_loss: 1.5364
# Epoch [   51/  100] | d_loss: 0.1149 | g_loss: 3.4673
# Epoch [   52/  100] | d_loss: 0.2075 | g_loss: 3.6360
# Epoch [   52/  100] | d_loss: 0.7678 | g_loss: 3.7646
# Epoch [   52/  100] | d_loss: 0.1484 | g_loss: 3.9603
# Epoch [   52/  100] | d_loss: 0.0710 | g_loss: 3.7295
# Epoch [   52/  100] | d_loss: 0.1185 | g_loss: 3.1202
# Epoch [   52/  100] | d_loss: 0.6566 | g_loss: 2.1932
# Epoch [   52/  100] | d_loss: 0.1271 | g_loss: 4.1491
# Epoch [   52/  100] | d_loss: 0.0559 | g_loss: 4.4889
# Epoch [   52/  100] | d_loss: 0.1228 | g_loss: 3.5724
# Epoch [   52/  100] | d_loss: 1.3297 | g_loss: 0.7418
# Epoch [   52/  100] | d_loss: 0.2863 | g_loss: 4.4824
# Epoch [   52/  100] | d_loss: 0.0870 | g_loss: 4.5421
# Epoch [   52/  100] | d_loss: 0.3070 | g_loss: 2.7606
# Epoch [   52/  100] | d_loss: 0.5833 | g_loss: 2.0172
# Epoch [   52/  100] | d_loss: 0.1529 | g_loss: 3.4900
# Epoch [   53/  100] | d_loss: 0.1167 | g_loss: 3.9338
# Epoch [   53/  100] | d_loss: 0.0984 | g_loss: 3.2152
# Epoch [   53/  100] | d_loss: 0.0893 | g_loss: 3.9754
# Epoch [   53/  100] | d_loss: 0.1058 | g_loss: 3.6867
# Epoch [   53/  100] | d_loss: 0.0949 | g_loss: 3.8846
# Epoch [   53/  100] | d_loss: 0.1027 | g_loss: 3.8440
# Epoch [   53/  100] | d_loss: 0.0910 | g_loss: 4.0583
# Epoch [   53/  100] | d_loss: 0.0795 | g_loss: 4.0139
# Epoch [   53/  100] | d_loss: 0.3099 | g_loss: 3.8490
# Epoch [   53/  100] | d_loss: 0.0939 | g_loss: 4.1393
# Epoch [   53/  100] | d_loss: 0.0844 | g_loss: 3.7353
# Epoch [   53/  100] | d_loss: 0.0975 | g_loss: 3.0694
# Epoch [   53/  100] | d_loss: 0.2131 | g_loss: 2.3658
# Epoch [   53/  100] | d_loss: 0.0918 | g_loss: 4.6795
# Epoch [   53/  100] | d_loss: 1.2660 | g_loss: 1.5065
# Epoch [   54/  100] | d_loss: 1.3748 | g_loss: 0.8592
# Epoch [   54/  100] | d_loss: 0.3624 | g_loss: 2.3862
# Epoch [   54/  100] | d_loss: 0.1733 | g_loss: 3.7665
# Epoch [   54/  100] | d_loss: 0.1111 | g_loss: 3.3775
# Epoch [   54/  100] | d_loss: 0.0963 | g_loss: 3.2390
# Epoch [   54/  100] | d_loss: 0.1230 | g_loss: 4.0706
# Epoch [   54/  100] | d_loss: 0.0953 | g_loss: 4.5297
# Epoch [   54/  100] | d_loss: 1.1951 | g_loss: 0.7042
# Epoch [   54/  100] | d_loss: 0.1151 | g_loss: 4.3099
# Epoch [   54/  100] | d_loss: 0.6986 | g_loss: 2.1345
# Epoch [   54/  100] | d_loss: 1.7939 | g_loss: 5.6484
# Epoch [   54/  100] | d_loss: 0.2879 | g_loss: 4.4521
# Epoch [   54/  100] | d_loss: 0.1559 | g_loss: 3.4514
# Epoch [   54/  100] | d_loss: 0.0679 | g_loss: 4.1563
# Epoch [   54/  100] | d_loss: 0.1095 | g_loss: 4.2493
# Epoch [   55/  100] | d_loss: 0.0983 | g_loss: 4.2862
# Epoch [   55/  100] | d_loss: 0.0867 | g_loss: 3.9752
# Epoch [   55/  100] | d_loss: 0.0656 | g_loss: 4.9232
# Epoch [   55/  100] | d_loss: 0.1032 | g_loss: 4.8040
# Epoch [   55/  100] | d_loss: 0.0962 | g_loss: 2.9371
# Epoch [   55/  100] | d_loss: 0.1359 | g_loss: 4.0745
# Epoch [   55/  100] | d_loss: 0.0652 | g_loss: 3.9803
# Epoch [   55/  100] | d_loss: 0.1635 | g_loss: 2.4530
# Epoch [   55/  100] | d_loss: 0.0862 | g_loss: 3.0793
# Epoch [   55/  100] | d_loss: 0.8595 | g_loss: 2.2868
# Epoch [   55/  100] | d_loss: 0.5982 | g_loss: 3.3142
# Epoch [   55/  100] | d_loss: 0.3330 | g_loss: 2.9590
# Epoch [   55/  100] | d_loss: 0.1423 | g_loss: 4.3918
# Epoch [   55/  100] | d_loss: 0.1112 | g_loss: 3.5912
# Epoch [   55/  100] | d_loss: 0.3889 | g_loss: 5.7057
# Epoch [   56/  100] | d_loss: 0.1491 | g_loss: 3.7626
# Epoch [   56/  100] | d_loss: 0.1386 | g_loss: 2.9985
# Epoch [   56/  100] | d_loss: 0.1876 | g_loss: 4.9324
# Epoch [   56/  100] | d_loss: 1.1820 | g_loss: 2.1227
# Epoch [   56/  100] | d_loss: 0.6314 | g_loss: 4.9491
# Epoch [   56/  100] | d_loss: 0.1724 | g_loss: 3.7494
# Epoch [   56/  100] | d_loss: 0.1131 | g_loss: 3.4920
# Epoch [   56/  100] | d_loss: 0.1618 | g_loss: 2.5813
# Epoch [   56/  100] | d_loss: 0.0586 | g_loss: 4.2858
# Epoch [   56/  100] | d_loss: 0.0907 | g_loss: 4.1339
# Epoch [   56/  100] | d_loss: 0.0721 | g_loss: 3.5362
# Epoch [   56/  100] | d_loss: 0.0741 | g_loss: 3.8867
# Epoch [   56/  100] | d_loss: 0.0440 | g_loss: 4.8044
# Epoch [   56/  100] | d_loss: 0.5767 | g_loss: 1.5612
# Epoch [   56/  100] | d_loss: 1.1521 | g_loss: 1.0117
# Epoch [   57/  100] | d_loss: 1.1859 | g_loss: 1.5907
# Epoch [   57/  100] | d_loss: 0.2041 | g_loss: 3.4649
# Epoch [   57/  100] | d_loss: 0.1371 | g_loss: 4.3285
# Epoch [   57/  100] | d_loss: 0.1044 | g_loss: 4.1853
# Epoch [   57/  100] | d_loss: 0.8174 | g_loss: 2.4711
# Epoch [   57/  100] | d_loss: 0.1203 | g_loss: 3.7593
# Epoch [   57/  100] | d_loss: 0.0734 | g_loss: 3.9049
# Epoch [   57/  100] | d_loss: 0.1177 | g_loss: 3.8658
# Epoch [   57/  100] | d_loss: 0.0572 | g_loss: 4.2468
# Epoch [   57/  100] | d_loss: 0.1235 | g_loss: 4.6188
# Epoch [   57/  100] | d_loss: 0.3868 | g_loss: 2.8366
# Epoch [   57/  100] | d_loss: 0.2151 | g_loss: 3.1646
# Epoch [   57/  100] | d_loss: 0.1493 | g_loss: 4.0897
# Epoch [   57/  100] | d_loss: 0.1174 | g_loss: 3.6073
# Epoch [   57/  100] | d_loss: 0.1077 | g_loss: 5.1912
# Epoch [   58/  100] | d_loss: 1.0625 | g_loss: 0.3180
# Epoch [   58/  100] | d_loss: 0.1270 | g_loss: 4.0406
# Epoch [   58/  100] | d_loss: 0.1040 | g_loss: 3.5816
# Epoch [   58/  100] | d_loss: 0.0452 | g_loss: 4.7544
# Epoch [   58/  100] | d_loss: 0.0672 | g_loss: 4.0396
# Epoch [   58/  100] | d_loss: 0.1258 | g_loss: 5.1462
# Epoch [   58/  100] | d_loss: 0.0815 | g_loss: 3.8071
# Epoch [   58/  100] | d_loss: 0.0439 | g_loss: 4.7585
# Epoch [   58/  100] | d_loss: 0.1139 | g_loss: 5.7098
# Epoch [   58/  100] | d_loss: 0.0800 | g_loss: 4.1164
# Epoch [   58/  100] | d_loss: 0.0744 | g_loss: 4.0277
# Epoch [   58/  100] | d_loss: 0.0888 | g_loss: 4.8551
# Epoch [   58/  100] | d_loss: 3.3220 | g_loss: 5.0233
# Epoch [   58/  100] | d_loss: 0.5405 | g_loss: 3.3608
# Epoch [   58/  100] | d_loss: 0.2292 | g_loss: 5.1301
# Epoch [   59/  100] | d_loss: 0.1449 | g_loss: 4.6944
# Epoch [   59/  100] | d_loss: 0.0845 | g_loss: 4.7331
# Epoch [   59/  100] | d_loss: 0.0923 | g_loss: 4.1206
# Epoch [   59/  100] | d_loss: 0.1045 | g_loss: 4.1826
# Epoch [   59/  100] | d_loss: 0.1117 | g_loss: 3.9797
# Epoch [   59/  100] | d_loss: 0.0726 | g_loss: 4.5885
# Epoch [   59/  100] | d_loss: 1.1324 | g_loss: 0.4832
# Epoch [   59/  100] | d_loss: 0.1687 | g_loss: 3.7452
# Epoch [   59/  100] | d_loss: 0.1318 | g_loss: 4.3881
# Epoch [   59/  100] | d_loss: 3.3922 | g_loss: 2.9199
# Epoch [   59/  100] | d_loss: 0.1145 | g_loss: 4.1304
# Epoch [   59/  100] | d_loss: 0.1304 | g_loss: 3.2535
# Epoch [   59/  100] | d_loss: 0.0766 | g_loss: 4.1593
# Epoch [   59/  100] | d_loss: 0.1576 | g_loss: 3.0319
# Epoch [   59/  100] | d_loss: 0.1960 | g_loss: 2.2466
# Epoch [   60/  100] | d_loss: 0.1260 | g_loss: 3.6738
# Epoch [   60/  100] | d_loss: 0.0724 | g_loss: 4.2155
# Epoch [   60/  100] | d_loss: 0.0742 | g_loss: 4.2453
# ...
# Epoch [   81/  100] | d_loss: 0.0404 | g_loss: 4.6570
# Epoch [   81/  100] | d_loss: 0.0506 | g_loss: 4.9863
# Epoch [   81/  100] | d_loss: 0.0849 | g_loss: 4.2883
# Epoch [   81/  100] | d_loss: 0.0333 | g_loss: 5.4665
# Epoch [   81/  100] | d_loss: 0.0530 | g_loss: 4.8904
# Epoch [   81/  100] | d_loss: 0.0585 | g_loss: 5.1199
# Epoch [   81/  100] | d_loss: 0.0350 | g_loss: 5.0967
# Epoch [   81/  100] | d_loss: 0.0647 | g_loss: 3.8828
# Epoch [   81/  100] | d_loss: 0.0351 | g_loss: 5.0652
# Epoch [   81/  100] | d_loss: 0.0532 | g_loss: 3.9260
# Epoch [   81/  100] | d_loss: 0.1127 | g_loss: 2.0615
# Epoch [   82/  100] | d_loss: 0.1179 | g_loss: 2.8866
# Epoch [   82/  100] | d_loss: 0.0311 | g_loss: 5.6604
# Epoch [   82/  100] | d_loss: 0.0371 | g_loss: 4.6977
# Epoch [   82/  100] | d_loss: 0.0758 | g_loss: 4.7712
# Epoch [   82/  100] | d_loss: 1.1384 | g_loss: 1.4299
# Epoch [   82/  100] | d_loss: 0.5028 | g_loss: 2.5504
# Epoch [   82/  100] | d_loss: 0.1565 | g_loss: 3.7394
# Epoch [   82/  100] | d_loss: 2.8330 | g_loss: 0.6826
# Epoch [   82/  100] | d_loss: 0.0866 | g_loss: 4.9138
# Epoch [   82/  100] | d_loss: 0.0742 | g_loss: 4.7628
# Epoch [   82/  100] | d_loss: 0.0643 | g_loss: 5.1404
# Epoch [   82/  100] | d_loss: 0.0556 | g_loss: 4.2351
# Epoch [   82/  100] | d_loss: 0.0734 | g_loss: 4.4047
# Epoch [   82/  100] | d_loss: 0.0647 | g_loss: 4.8240
# Epoch [   82/  100] | d_loss: 0.0878 | g_loss: 4.9174
# Epoch [   83/  100] | d_loss: 0.0966 | g_loss: 5.2208
# Epoch [   83/  100] | d_loss: 0.1511 | g_loss: 6.3332
# Epoch [   83/  100] | d_loss: 0.0500 | g_loss: 5.4713
# Epoch [   83/  100] | d_loss: 0.0449 | g_loss: 5.2979
# Epoch [   83/  100] | d_loss: 0.0502 | g_loss: 4.0789
# Epoch [   83/  100] | d_loss: 0.0260 | g_loss: 4.8246
# Epoch [   83/  100] | d_loss: 1.5944 | g_loss: 0.6293
# Epoch [   83/  100] | d_loss: 0.7567 | g_loss: 2.1517
# Epoch [   83/  100] | d_loss: 0.2045 | g_loss: 4.5594
# Epoch [   83/  100] | d_loss: 0.1535 | g_loss: 4.2181
# Epoch [   83/  100] | d_loss: 0.7574 | g_loss: 1.3648
# Epoch [   83/  100] | d_loss: 0.1429 | g_loss: 4.0134
# Epoch [   83/  100] | d_loss: 0.1508 | g_loss: 3.1938
# Epoch [   83/  100] | d_loss: 0.0897 | g_loss: 4.9487
# Epoch [   83/  100] | d_loss: 0.0625 | g_loss: 4.2153
# Epoch [   84/  100] | d_loss: 0.0608 | g_loss: 4.3270
# Epoch [   84/  100] | d_loss: 0.0862 | g_loss: 4.2627
# Epoch [   84/  100] | d_loss: 0.0623 | g_loss: 4.5428
# Epoch [   84/  100] | d_loss: 0.6500 | g_loss: 1.6208
# Epoch [   84/  100] | d_loss: 0.2562 | g_loss: 5.6456
# Epoch [   84/  100] | d_loss: 0.0776 | g_loss: 4.5082
# Epoch [   84/  100] | d_loss: 0.0817 | g_loss: 3.1841
# Epoch [   84/  100] | d_loss: 0.0805 | g_loss: 4.0430
# Epoch [   84/  100] | d_loss: 0.0372 | g_loss: 5.5645
# Epoch [   84/  100] | d_loss: 0.4188 | g_loss: 3.5247
# Epoch [   84/  100] | d_loss: 0.0673 | g_loss: 4.5397
# Epoch [   84/  100] | d_loss: 0.0855 | g_loss: 5.5969
# Epoch [   84/  100] | d_loss: 0.0450 | g_loss: 5.1591
# Epoch [   84/  100] | d_loss: 0.0571 | g_loss: 4.1564
# Epoch [   84/  100] | d_loss: 0.0397 | g_loss: 4.7807
# Epoch [   85/  100] | d_loss: 0.0456 | g_loss: 4.7367
# Epoch [   85/  100] | d_loss: 0.0438 | g_loss: 5.1732
# Epoch [   85/  100] | d_loss: 0.0521 | g_loss: 4.2501
# Epoch [   85/  100] | d_loss: 0.0383 | g_loss: 4.7496
# Epoch [   85/  100] | d_loss: 0.0439 | g_loss: 5.4136
# Epoch [   85/  100] | d_loss: 0.0506 | g_loss: 5.0007
# Epoch [   85/  100] | d_loss: 0.0805 | g_loss: 5.0995
# Epoch [   85/  100] | d_loss: 3.5800 | g_loss: 4.9111
# Epoch [   85/  100] | d_loss: 0.3855 | g_loss: 3.9621
# Epoch [   85/  100] | d_loss: 0.1203 | g_loss: 4.3495
# Epoch [   85/  100] | d_loss: 0.0750 | g_loss: 4.7625
# Epoch [   85/  100] | d_loss: 0.0736 | g_loss: 5.0871
# Epoch [   85/  100] | d_loss: 0.1117 | g_loss: 4.2610
# Epoch [   85/  100] | d_loss: 2.2929 | g_loss: 0.2030
# Epoch [   85/  100] | d_loss: 0.2043 | g_loss: 4.6355
# Epoch [   86/  100] | d_loss: 0.2766 | g_loss: 5.7426
# Epoch [   86/  100] | d_loss: 0.1688 | g_loss: 2.6877
# Epoch [   86/  100] | d_loss: 0.1116 | g_loss: 4.1364
# Epoch [   86/  100] | d_loss: 0.0848 | g_loss: 4.7038
# Epoch [   86/  100] | d_loss: 0.0930 | g_loss: 4.9678
# Epoch [   86/  100] | d_loss: 0.0553 | g_loss: 4.5720
# Epoch [   86/  100] | d_loss: 0.0829 | g_loss: 4.0033
# Epoch [   86/  100] | d_loss: 0.0638 | g_loss: 3.8663
# Epoch [   86/  100] | d_loss: 0.0467 | g_loss: 4.0462
# Epoch [   86/  100] | d_loss: 0.0335 | g_loss: 4.9423
# Epoch [   86/  100] | d_loss: 0.0646 | g_loss: 4.6607
# Epoch [   86/  100] | d_loss: 0.0559 | g_loss: 5.1331
# Epoch [   86/  100] | d_loss: 0.0585 | g_loss: 4.6665
# Epoch [   86/  100] | d_loss: 0.0586 | g_loss: 3.5999
# Epoch [   86/  100] | d_loss: 0.0493 | g_loss: 4.7923
# Epoch [   87/  100] | d_loss: 0.0397 | g_loss: 4.8286
# Epoch [   87/  100] | d_loss: 3.6335 | g_loss: 6.9443
# Epoch [   87/  100] | d_loss: 2.2556 | g_loss: 0.9507
# Epoch [   87/  100] | d_loss: 3.9003 | g_loss: 5.7554
# Epoch [   87/  100] | d_loss: 0.1580 | g_loss: 4.1179
# Epoch [   87/  100] | d_loss: 0.1445 | g_loss: 4.7491
# Epoch [   87/  100] | d_loss: 0.0545 | g_loss: 4.6397
# Epoch [   87/  100] | d_loss: 0.1402 | g_loss: 5.3830
# Epoch [   87/  100] | d_loss: 0.0553 | g_loss: 4.4270
# Epoch [   87/  100] | d_loss: 0.1540 | g_loss: 3.0671
# Epoch [   87/  100] | d_loss: 0.0697 | g_loss: 4.9059
# Epoch [   87/  100] | d_loss: 0.1805 | g_loss: 4.2849
# Epoch [   87/  100] | d_loss: 0.6283 | g_loss: 3.5742
# Epoch [   87/  100] | d_loss: 0.1383 | g_loss: 4.3178
# Epoch [   87/  100] | d_loss: 0.0547 | g_loss: 5.3528
# Epoch [   88/  100] | d_loss: 0.0989 | g_loss: 4.2505
# Epoch [   88/  100] | d_loss: 0.0695 | g_loss: 5.3102
# Epoch [   88/  100] | d_loss: 0.0491 | g_loss: 5.7047
# Epoch [   88/  100] | d_loss: 0.0329 | g_loss: 5.4754
# Epoch [   88/  100] | d_loss: 0.0857 | g_loss: 4.4863
# Epoch [   88/  100] | d_loss: 0.0396 | g_loss: 4.6109
# Epoch [   88/  100] | d_loss: 0.0527 | g_loss: 4.9424
# Epoch [   88/  100] | d_loss: 0.0525 | g_loss: 5.1337
# Epoch [   88/  100] | d_loss: 0.0614 | g_loss: 5.4555
# Epoch [   88/  100] | d_loss: 0.0303 | g_loss: 5.4433
# Epoch [   88/  100] | d_loss: 0.0517 | g_loss: 5.4209
# Epoch [   88/  100] | d_loss: 0.0191 | g_loss: 6.4895
# Epoch [   88/  100] | d_loss: 0.0634 | g_loss: 5.5239
# Epoch [   88/  100] | d_loss: 0.0392 | g_loss: 5.1723
# Epoch [   88/  100] | d_loss: 0.0466 | g_loss: 3.8948
# Epoch [   89/  100] | d_loss: 0.0700 | g_loss: 4.6448
# Epoch [   89/  100] | d_loss: 4.2749 | g_loss: 3.9079
# Epoch [   89/  100] | d_loss: 0.7340 | g_loss: 3.3182
# Epoch [   89/  100] | d_loss: 0.4655 | g_loss: 5.2102
# Epoch [   89/  100] | d_loss: 0.0921 | g_loss: 5.5923
# Epoch [   89/  100] | d_loss: 0.2463 | g_loss: 4.4367
# Epoch [   89/  100] | d_loss: 0.1797 | g_loss: 5.3795
# Epoch [   89/  100] | d_loss: 0.0632 | g_loss: 4.0804
# Epoch [   89/  100] | d_loss: 0.0728 | g_loss: 4.4062
# Epoch [   89/  100] | d_loss: 0.1327 | g_loss: 5.3001
# Epoch [   89/  100] | d_loss: 0.0603 | g_loss: 5.4584
# Epoch [   89/  100] | d_loss: 0.1848 | g_loss: 5.5619
# Epoch [   89/  100] | d_loss: 0.0919 | g_loss: 4.1261
# Epoch [   89/  100] | d_loss: 0.0520 | g_loss: 4.4640
# Epoch [   89/  100] | d_loss: 0.0841 | g_loss: 4.2252
# Epoch [   90/  100] | d_loss: 0.0395 | g_loss: 4.8312
# Epoch [   90/  100] | d_loss: 0.0620 | g_loss: 5.5812
# Epoch [   90/  100] | d_loss: 0.0220 | g_loss: 4.9168
# Epoch [   90/  100] | d_loss: 0.1183 | g_loss: 6.3998
# Epoch [   90/  100] | d_loss: 0.4977 | g_loss: 3.7154
# Epoch [   90/  100] | d_loss: 0.3282 | g_loss: 2.7369
# Epoch [   90/  100] | d_loss: 0.0706 | g_loss: 4.7176
# Epoch [   90/  100] | d_loss: 0.8498 | g_loss: 7.8627
# Epoch [   90/  100] | d_loss: 2.7309 | g_loss: 6.3423
# Epoch [   90/  100] | d_loss: 0.1560 | g_loss: 3.3546
# Epoch [   90/  100] | d_loss: 0.0701 | g_loss: 5.2283
# Epoch [   90/  100] | d_loss: 0.0436 | g_loss: 4.7910
# Epoch [   90/  100] | d_loss: 0.0991 | g_loss: 4.7456
# Epoch [   90/  100] | d_loss: 0.0373 | g_loss: 4.5947
# Epoch [   90/  100] | d_loss: 0.2057 | g_loss: 5.4955
# Epoch [   91/  100] | d_loss: 0.1599 | g_loss: 4.6051
# Epoch [   91/  100] | d_loss: 0.1012 | g_loss: 4.7231
# Epoch [   91/  100] | d_loss: 0.0343 | g_loss: 5.7982
# Epoch [   91/  100] | d_loss: 0.0452 | g_loss: 4.5744
# Epoch [   91/  100] | d_loss: 0.0663 | g_loss: 5.2020
# Epoch [   91/  100] | d_loss: 0.0656 | g_loss: 4.1322
# Epoch [   91/  100] | d_loss: 0.0461 | g_loss: 4.8111
# Epoch [   91/  100] | d_loss: 0.0364 | g_loss: 5.2284
# Epoch [   91/  100] | d_loss: 0.0900 | g_loss: 3.4407
# Epoch [   91/  100] | d_loss: 0.4040 | g_loss: 3.9913
# Epoch [   91/  100] | d_loss: 2.0640 | g_loss: 0.1587
# Epoch [   91/  100] | d_loss: 0.1400 | g_loss: 4.1797
# Epoch [   91/  100] | d_loss: 0.1055 | g_loss: 4.7543
# Epoch [   91/  100] | d_loss: 0.0343 | g_loss: 5.3639
# Epoch [   91/  100] | d_loss: 0.1577 | g_loss: 6.5226
# Epoch [   92/  100] | d_loss: 0.1308 | g_loss: 5.8746
# Epoch [   92/  100] | d_loss: 0.0414 | g_loss: 4.7477
# Epoch [   92/  100] | d_loss: 0.0412 | g_loss: 4.9749
# Epoch [   92/  100] | d_loss: 0.1142 | g_loss: 5.7300
# Epoch [   92/  100] | d_loss: 0.1214 | g_loss: 4.4868
# Epoch [   92/  100] | d_loss: 0.0628 | g_loss: 5.3244
# Epoch [   92/  100] | d_loss: 0.0384 | g_loss: 6.2012
# Epoch [   92/  100] | d_loss: 0.0511 | g_loss: 4.4205
# Epoch [   92/  100] | d_loss: 0.0814 | g_loss: 6.1482
# Epoch [   92/  100] | d_loss: 0.0374 | g_loss: 4.3012
# Epoch [   92/  100] | d_loss: 0.0312 | g_loss: 5.1761
# Epoch [   92/  100] | d_loss: 0.0484 | g_loss: 4.8776
# Epoch [   92/  100] | d_loss: 0.0553 | g_loss: 3.9633
# Epoch [   92/  100] | d_loss: 0.0452 | g_loss: 5.6959
# Epoch [   92/  100] | d_loss: 0.0363 | g_loss: 5.5046
# Epoch [   93/  100] | d_loss: 0.0291 | g_loss: 5.0868
# Epoch [   93/  100] | d_loss: 0.0311 | g_loss: 5.2084
# Epoch [   93/  100] | d_loss: 0.0400 | g_loss: 6.1839
# Epoch [   93/  100] | d_loss: 0.0272 | g_loss: 6.2284
# Epoch [   93/  100] | d_loss: 1.0150 | g_loss: 1.8984
# Epoch [   93/  100] | d_loss: 0.8629 | g_loss: 3.6220
# Epoch [   93/  100] | d_loss: 0.1884 | g_loss: 4.6441
# Epoch [   93/  100] | d_loss: 0.1297 | g_loss: 4.2798
# Epoch [   93/  100] | d_loss: 0.0647 | g_loss: 4.4092
# Epoch [   93/  100] | d_loss: 0.0872 | g_loss: 3.4965
# Epoch [   93/  100] | d_loss: 0.0196 | g_loss: 5.4095
# Epoch [   93/  100] | d_loss: 0.9690 | g_loss: 1.8540
# Epoch [   93/  100] | d_loss: 0.1119 | g_loss: 4.5481
# Epoch [   93/  100] | d_loss: 0.0575 | g_loss: 5.1752
# Epoch [   93/  100] | d_loss: 0.0780 | g_loss: 4.8884
# Epoch [   94/  100] | d_loss: 0.2278 | g_loss: 6.6277
# Epoch [   94/  100] | d_loss: 0.0336 | g_loss: 5.3139
# Epoch [   94/  100] | d_loss: 0.1027 | g_loss: 3.3245
# Epoch [   94/  100] | d_loss: 0.0850 | g_loss: 5.2898
# Epoch [   94/  100] | d_loss: 0.0646 | g_loss: 6.6996
# Epoch [   94/  100] | d_loss: 0.0473 | g_loss: 5.4887
# Epoch [   94/  100] | d_loss: 0.0280 | g_loss: 4.7894
# Epoch [   94/  100] | d_loss: 0.0264 | g_loss: 4.8197
# Epoch [   94/  100] | d_loss: 1.5373 | g_loss: 0.9787
# Epoch [   94/  100] | d_loss: 0.3493 | g_loss: 4.2133
# Epoch [   94/  100] | d_loss: 0.0841 | g_loss: 3.4897
# Epoch [   94/  100] | d_loss: 0.0884 | g_loss: 3.9517
# Epoch [   94/  100] | d_loss: 0.0672 | g_loss: 4.9935
# Epoch [   94/  100] | d_loss: 0.2185 | g_loss: 7.5100
# Epoch [   94/  100] | d_loss: 0.0367 | g_loss: 5.3069
# Epoch [   95/  100] | d_loss: 0.0369 | g_loss: 5.7149
# Epoch [   95/  100] | d_loss: 0.0234 | g_loss: 5.7948
# Epoch [   95/  100] | d_loss: 6.2172 | g_loss: 0.3021
# Epoch [   95/  100] | d_loss: 1.1928 | g_loss: 1.5637
# Epoch [   95/  100] | d_loss: 0.4220 | g_loss: 2.1437
# Epoch [   95/  100] | d_loss: 0.1853 | g_loss: 3.8244
# Epoch [   95/  100] | d_loss: 2.0019 | g_loss: 0.4524
# Epoch [   95/  100] | d_loss: 0.1482 | g_loss: 4.9172
# Epoch [   95/  100] | d_loss: 0.1017 | g_loss: 3.4776
# Epoch [   95/  100] | d_loss: 0.1834 | g_loss: 4.8124
# Epoch [   95/  100] | d_loss: 0.0631 | g_loss: 4.1077
# Epoch [   95/  100] | d_loss: 0.0549 | g_loss: 5.0469
# Epoch [   95/  100] | d_loss: 0.0681 | g_loss: 4.0896
# Epoch [   95/  100] | d_loss: 0.0623 | g_loss: 3.1528
# Epoch [   95/  100] | d_loss: 0.0558 | g_loss: 4.6256
# Epoch [   96/  100] | d_loss: 0.0312 | g_loss: 5.3891
# Epoch [   96/  100] | d_loss: 0.0337 | g_loss: 4.8760
# Epoch [   96/  100] | d_loss: 0.0278 | g_loss: 4.8045
# Epoch [   96/  100] | d_loss: 0.0493 | g_loss: 4.4073
# Epoch [   96/  100] | d_loss: 0.0549 | g_loss: 5.4469
# Epoch [   96/  100] | d_loss: 0.0457 | g_loss: 5.0044
# Epoch [   96/  100] | d_loss: 0.0753 | g_loss: 5.8826
# Epoch [   96/  100] | d_loss: 0.0317 | g_loss: 4.8609
# Epoch [   96/  100] | d_loss: 0.0580 | g_loss: 4.8634
# Epoch [   96/  100] | d_loss: 0.0280 | g_loss: 4.7948
# Epoch [   96/  100] | d_loss: 0.0382 | g_loss: 5.9585
# Epoch [   96/  100] | d_loss: 0.0241 | g_loss: 5.2949
# Epoch [   96/  100] | d_loss: 0.0332 | g_loss: 4.4834
# Epoch [   96/  100] | d_loss: 0.0688 | g_loss: 6.1210
# Epoch [   96/  100] | d_loss: 0.0491 | g_loss: 4.7627
# Epoch [   97/  100] | d_loss: 0.0547 | g_loss: 5.5793
# Epoch [   97/  100] | d_loss: 1.1598 | g_loss: 0.8699
# Epoch [   97/  100] | d_loss: 0.7276 | g_loss: 1.1727
# Epoch [   97/  100] | d_loss: 0.3202 | g_loss: 4.3578
# Epoch [   97/  100] | d_loss: 0.0503 | g_loss: 4.9691
# Epoch [   97/  100] | d_loss: 1.9484 | g_loss: 1.4087
# Epoch [   97/  100] | d_loss: 0.2337 | g_loss: 2.9617
# Epoch [   97/  100] | d_loss: 0.0624 | g_loss: 5.9977
# Epoch [   97/  100] | d_loss: 0.0734 | g_loss: 5.5006
# Epoch [   97/  100] | d_loss: 0.0780 | g_loss: 5.8895
# Epoch [   97/  100] | d_loss: 0.0885 | g_loss: 3.8066
# Epoch [   97/  100] | d_loss: 0.0408 | g_loss: 4.4265
# Epoch [   97/  100] | d_loss: 0.0456 | g_loss: 5.1396
# Epoch [   97/  100] | d_loss: 0.1007 | g_loss: 4.5141
# Epoch [   97/  100] | d_loss: 0.0414 | g_loss: 4.8624
# Epoch [   98/  100] | d_loss: 0.0247 | g_loss: 6.0427
# Epoch [   98/  100] | d_loss: 3.6795 | g_loss: 4.3528
# Epoch [   98/  100] | d_loss: 0.3979 | g_loss: 3.0112
# Epoch [   98/  100] | d_loss: 0.4270 | g_loss: 1.2577
# Epoch [   98/  100] | d_loss: 0.1394 | g_loss: 4.2765
# Epoch [   98/  100] | d_loss: 0.0566 | g_loss: 4.0879
# Epoch [   98/  100] | d_loss: 0.0385 | g_loss: 4.5789
# Epoch [   98/  100] | d_loss: 0.1169 | g_loss: 4.5431
# Epoch [   98/  100] | d_loss: 0.0460 | g_loss: 5.7741
# Epoch [   98/  100] | d_loss: 0.1029 | g_loss: 4.7332
# Epoch [   98/  100] | d_loss: 0.5400 | g_loss: 3.6124
# Epoch [   98/  100] | d_loss: 0.0627 | g_loss: 5.8814
# Epoch [   98/  100] | d_loss: 0.0431 | g_loss: 5.2967
# Epoch [   98/  100] | d_loss: 0.0346 | g_loss: 5.8297
# Epoch [   98/  100] | d_loss: 0.0426 | g_loss: 5.4985
# Epoch [   99/  100] | d_loss: 0.0321 | g_loss: 6.4508
# Epoch [   99/  100] | d_loss: 0.2132 | g_loss: 7.3144
# Epoch [   99/  100] | d_loss: 0.0414 | g_loss: 4.7920
# Epoch [   99/  100] | d_loss: 0.0504 | g_loss: 4.7751
# Epoch [   99/  100] | d_loss: 0.0582 | g_loss: 4.1329
# Epoch [   99/  100] | d_loss: 0.0948 | g_loss: 3.2147
# Epoch [   99/  100] | d_loss: 0.0343 | g_loss: 3.9052
# Epoch [   99/  100] | d_loss: 0.1061 | g_loss: 5.5079
# Epoch [   99/  100] | d_loss: 0.0482 | g_loss: 5.1199
# Epoch [   99/  100] | d_loss: 0.1475 | g_loss: 4.7517
# Epoch [   99/  100] | d_loss: 0.6336 | g_loss: 2.4397
# Epoch [   99/  100] | d_loss: 1.0014 | g_loss: 1.6670
# Epoch [   99/  100] | d_loss: 0.0777 | g_loss: 4.8009
# Epoch [   99/  100] | d_loss: 0.0604 | g_loss: 5.7001
# Epoch [   99/  100] | d_loss: 0.1011 | g_loss: 4.5420
# Epoch [  100/  100] | d_loss: 0.0808 | g_loss: 4.6608
# Epoch [  100/  100] | d_loss: 0.0665 | g_loss: 3.8774
# Epoch [  100/  100] | d_loss: 0.0307 | g_loss: 5.5426
# Epoch [  100/  100] | d_loss: 0.0305 | g_loss: 5.2784
# Epoch [  100/  100] | d_loss: 0.0352 | g_loss: 4.5182
# Epoch [  100/  100] | d_loss: 0.0386 | g_loss: 4.6339
# Epoch [  100/  100] | d_loss: 0.0236 | g_loss: 5.2898
# Epoch [  100/  100] | d_loss: 0.0791 | g_loss: 6.5861
# Epoch [  100/  100] | d_loss: 0.4614 | g_loss: 2.6741
# Epoch [  100/  100] | d_loss: 0.2286 | g_loss: 4.5590
# Epoch [  100/  100] | d_loss: 0.0504 | g_loss: 4.4394
# Epoch [  100/  100] | d_loss: 0.0474 | g_loss: 4.5964
# Epoch [  100/  100] | d_loss: 0.0347 | g_loss: 5.1116
# Epoch [  100/  100] | d_loss: 0.3536 | g_loss: 4.2402
# Epoch [  100/  100] | d_loss: 0.1067 | g_loss: 5.3136

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# The generated look like a real person if not looking at details.  However, I pay closer attension to the image, some sample has a mismatched facial features, like the hair is not matched and those nose is too narror, most of the time are male facial feature on woman or vice versa.
#
# I train the model with 100 epochs and the sample looks better but not notice big different.  To improve quality, a higher resolution images and a higher epochs are necessary but the training time will be much longer.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
